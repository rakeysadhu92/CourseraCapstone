# %% [markdown]
# ## Part I. Scraping Table From Wiki Page

# %%
import pandas as pd
import numpy as np


#reading html page for table
tables = pd.read_html("https://en.wikipedia.org/wiki/List_of_postal_codes_of_Canada:_M", header = 0)


table = tables[0]                      #identifying the table 
df = pd.DataFrame(table)               #converting table to dataframe
df = df[df.Borough != 'Not assigned']  #dropping records where borough is not assigned
df.sort_values('Postcode')             #sorting to see multiple neighborhoods with the same postcode


#identifying neighborhoods with the same postcode and convert to a list
lst = []
nbhds = []
for pc in df['Postcode']:
    lst = df.loc[df['Postcode'] == pc]['Neighbourhood'].tolist()
    nbhds.append(', '.join(lst))


df['Neighbourhood'] = nbhds            #listing neighborhoods with the same postcode together
df.loc[df['Neighbourhood'] == 'Not assigned', 'Neighbourhood'] = df['Borough'] #assign "Not assigned" neighborhoods the same name as their borough
df.drop_duplicates(inplace = True)     #drop dupicate rows
df = df.reset_index(drop = True)       #reset index
df.head(10)                            #display first 10 rows table
# Out:
#   Postcode           Borough                     Neighbourhood
# 0      M3A        North York                         Parkwoods
# 1      M4A        North York                  Victoria Village
# 2      M5A  Downtown Toronto         Harbourfront, Regent Park
# 3      M6A        North York  Lawrence Heights, Lawrence Manor
# 4      M7A      Queen's Park                      Queen's Park
# 5      M9A         Etobicoke                  Islington Avenue
# 6      M1B       Scarborough                    Rouge, Malvern
# 7      M3B        North York                   Don Mills North
# 8      M4B         East York   Woodbine Gardens, Parkview Hill
# 9      M5B  Downtown Toronto          Ryerson, Garden District

# %% [markdown]
# ## Part II. Geographical Coordinates For Each Neighborhood

# %%
df_geospatial = pd.read_csv('https://cocl.us/Geospatial_data')               #importing csv
df_geospatial.rename(columns = {'Postal Code': 'Postcode'}, inplace = True)  #rename post code column to match with table above
df = df.join(df_geospatial.set_index('Postcode'), on='Postcode')             #join the dataframe on "postcode" to include the geospatial coords
df.head(10)                                                                  #show first 10 rows of new dataframe
# Out:
#   Postcode           Borough                     Neighbourhood   Latitude  \
# 0      M3A        North York                         Parkwoods  43.753259
# 1      M4A        North York                  Victoria Village  43.725882
# 2      M5A  Downtown Toronto         Harbourfront, Regent Park  43.654260
# 3      M6A        North York  Lawrence Heights, Lawrence Manor  43.718518
# 4      M7A      Queen's Park                      Queen's Park  43.662301
# 5      M9A         Etobicoke                  Islington Avenue  43.667856
# 6      M1B       Scarborough                    Rouge, Malvern  43.806686
# 7      M3B        North York                   Don Mills North  43.745906
# 8      M4B         East York   Woodbine Gardens, Parkview Hill  43.706397
# 9      M5B  Downtown Toronto          Ryerson, Garden District  43.657162
#
#    Longitude
# 0 -79.329656
# 1 -79.315572
# 2 -79.360636
# 3 -79.464763
# 4 -79.389494
# 5 -79.532242
# 6 -79.194353
# 7 -79.352188
# 8 -79.309937
# 9 -79.378937

# %% [markdown]
# ## Part III. Explore/Cluster Toronto Data

# %%
# !conda install -c conda-forge folium=0.5.0 --yes
# Out:
# Solving environment: done
#
# ## Package Plan ##
#
#   environment location: /opt/conda/envs/Python36
#
#   added / updated specs:
#     - folium=0.5.0
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     vincent-0.4.4              |             py_1          28 KB  conda-forge
#     certifi-2019.9.11          |           py36_0         147 KB  conda-forge
#     openssl-1.1.1c             |       h516909a_0         2.1 MB  conda-forge
#     branca-0.3.1               |             py_0          25 KB  conda-forge
#     altair-3.2.0               |           py36_0         770 KB  conda-forge
#     folium-0.5.0               |             py_0          45 KB  conda-forge
#     ca-certificates-2019.9.11  |       hecc5488_0         144 KB  conda-forge
#     ------------------------------------------------------------
#                                            Total:         3.3 MB
#
# The following NEW packages will be INSTALLED:
#
#     altair:          3.2.0-py36_0      conda-forge
#     branca:          0.3.1-py_0        conda-forge
#     folium:          0.5.0-py_0        conda-forge
#     vincent:         0.4.4-py_1        conda-forge
#
# The following packages will be UPDATED:
#
#     ca-certificates: 2019.5.15-1                   --> 2019.9.11-hecc5488_0 conda-forge
#     certifi:         2019.6.16-py36_1              --> 2019.9.11-py36_0     conda-forge
#
# The following packages will be DOWNGRADED:
#
#     openssl:         1.1.1c-h7b6447c_1             --> 1.1.1c-h516909a_0    conda-forge
#
#
# Downloading and Extracting Packages
# vincent-0.4.4        | 28 KB     | ##################################### | 100%
# certifi-2019.9.11    | 147 KB    | ##################################### | 100%
# openssl-1.1.1c       | 2.1 MB    | ##################################### | 100%
# branca-0.3.1         | 25 KB     | ##################################### | 100%
# altair-3.2.0         | 770 KB    | ##################################### | 100%
# folium-0.5.0         | 45 KB     | ##################################### | 100%
# ca-certificates-2019 | 144 KB    | ##################################### | 100%
# Preparing transaction: done
# Verifying transaction: done
# Executing transaction: done

# %%
#import dependencies
import folium 
from geopy.geocoders import Nominatim
import requests
import matplotlib.cm as cm
import matplotlib.colors as colors
from sklearn.cluster import KMeans
import json
from pandas.io.json import json_normalize

# %%
#idenitfy foursquare API credentials
CLIENT_ID = 'YXO1CNCNUXNDNQXBKVPFQSKYLUN21BXFCIWFNHHQ2AF40QDT' # your Foursquare ID
CLIENT_SECRET = 'MFVPCBLEV0XDB3XIWJESJPLNLIIONZFOR541CZ4IVAQWD51S' # your Foursquare Secret
VERSION = '20180605' # Foursquare API version

print('Your credentails:')
print('CLIENT_ID: ' + CLIENT_ID)
print('CLIENT_SECRET:' + CLIENT_SECRET)
# Out:
# Your credentails:
# CLIENT_ID: YXO1CNCNUXNDNQXBKVPFQSKYLUN21BXFCIWFNHHQ2AF40QDT
# CLIENT_SECRET:MFVPCBLEV0XDB3XIWJESJPLNLIIONZFOR541CZ4IVAQWD51S

# %% [markdown]
# #### Getting the geographical coordinates of Toronto

# %%
address = 'Toronto, Ontario, Canada'

geolocator = Nominatim(user_agent="ny_explorer")
location = geolocator.geocode(address)
latitude = location.latitude
longitude = location.longitude
print('The geograpical coordinate of Toronto are {}, {}.'.format(latitude, longitude))
# Out:
# The geograpical coordinate of Toronto are 43.653963, -79.387207.

# %% [markdown]
# #### Creating map of Toronto with Neighborhood names

# %%
map_toronto = folium.Map(location=[latitude, longitude], zoom_start=10)

# add markers to map
for lat, lng, borough, neighborhood in zip(df['Latitude'], df['Longitude'], df['Borough'], df['Neighbourhood']):
    label = '{}, {}'.format(neighborhood, borough)
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
        [lat, lng],
        radius=5,
        popup=label,
        color='blue',
        fill=True,
        fill_color='#3186cc',
        fill_opacity=0.7,
        parse_html=False).add_to(map_toronto)  
    
map_toronto
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# #### Getting Top 100 venues within 5000 meters of Queen's Park

# %%
nbhd = 'Queen\'s Park' 
mask = df['Neighbourhood'].str.contains(nbhd)
nbhd_lat = df.loc[mask, 'Latitude'].iat[0]
nbhd_long = df.loc[mask, 'Longitude'].iat[0]

LIMIT = 100

radius = 5000 
url = 'https://api.foursquare.com/v2/venues/explore?&client_id={}&client_secret={}&v={}&ll={},{}&radius={}&limit={}'.format(
    CLIENT_ID, 
    CLIENT_SECRET, 
    VERSION, 
    nbhd_lat, 
    nbhd_long, 
    radius, 
    LIMIT)

results = requests.get(url).json()
print('The results are for the neighbordhood -', nbhd, 'located at', nbhd_lat, nbhd_long)
# Out:
# The results are for the neighbordhood - Queen's Park located at 43.6623015 -79.3894938

# %%
# function that extracts the category of the venue
def get_category_type(row):
    try:
        categories_list = row['categories']
    except:
        categories_list = row['venue.categories']
        
    if len(categories_list) == 0:
        return None
    else:
        return categories_list[0]['name']

# %% [markdown]
# #### Getting venues nearby Queen's Park

# %%
#create dataframe from results
venues = results['response']['groups'][0]['items']
    
nearby_venues = json_normalize(venues) # flatten JSON

# filter columns
filtered_columns = ['venue.name', 'venue.categories', 'venue.location.lat', 'venue.location.lng']
nearby_venues =nearby_venues.loc[:, filtered_columns]

# filter the category for each row
nearby_venues['venue.categories'] = nearby_venues.apply(get_category_type, axis=1)

# clean columns
nearby_venues.columns = [col.split(".")[-1] for col in nearby_venues.columns]

nearby_venues.head()
# Out:
#                    name      categories        lat        lng
# 0     DanceLifeX Centre    Dance Studio  43.666956 -79.385297
# 1        Jimmy's Coffee     Coffee Shop  43.658421 -79.385613
# 2         Hailed Coffee     Coffee Shop  43.658833 -79.383684
# 3          Banh Mi Boys  Sandwich Place  43.659292 -79.381949
# 4  Royal Ontario Museum          Museum  43.668367 -79.394813

# %%
print('{} venues were returned by Foursquare.'.format(nearby_venues.shape[0]))
# Out:
# 100 venues were returned by Foursquare.

# %% [markdown]
# #### Getting all venues in Toronto

# %%
def getNearbyVenues(names, latitudes, longitudes, radius=500):
    
    venues_list=[]
    for name, lat, lng in zip(names, latitudes, longitudes):
        print(name)
            
        # create the API request URL
        url = 'https://api.foursquare.com/v2/venues/explore?&client_id={}&client_secret={}&v={}&ll={},{}&radius={}&limit={}'.format(
            CLIENT_ID, 
            CLIENT_SECRET, 
            VERSION, 
            lat, 
            lng, 
            radius, 
            LIMIT)
            
        # make the GET request
        results = requests.get(url).json()["response"]['groups'][0]['items']
        
        # return only relevant information for each nearby venue
        venues_list.append([(
            name, 
            lat, 
            lng, 
            v['venue']['name'], 
            v['venue']['location']['lat'], 
            v['venue']['location']['lng'],  
            v['venue']['categories'][0]['name']) for v in results])

    nearby_venues = pd.DataFrame([item for venue_list in venues_list for item in venue_list])
    nearby_venues.columns = ['Neighborhood', 
                  'Neighborhood Latitude', 
                  'Neighborhood Longitude', 
                  'Venue', 
                  'Venue Latitude', 
                  'Venue Longitude', 
                  'Venue Category']
    return(nearby_venues)

# %%
toronto_venues = getNearbyVenues(names=df['Neighbourhood'], latitudes=df['Latitude'],longitudes=df['Longitude'])
print('There are {} unique categories.'.format(len(toronto_venues['Venue Category'].unique())))
# Out:
# Parkwoods
# Victoria Village
# Harbourfront, Regent Park
# Lawrence Heights, Lawrence Manor
# Queen's Park
# Islington Avenue
# Rouge, Malvern
# Don Mills North
# Woodbine Gardens, Parkview Hill
# Ryerson, Garden District
# Glencairn
# Cloverdale, Islington, Martin Grove, Princess Gardens, West Deane Park
# Highland Creek, Rouge Hill, Port Union
# Flemingdon Park, Don Mills South
# Woodbine Heights
# St. James Town
# Humewood-Cedarvale
# Bloordale Gardens, Eringate, Markland Wood, Old Burnhamthorpe
# Guildwood, Morningside, West Hill
# The Beaches
# Berczy Park
# Caledonia-Fairbanks
# Woburn
# Leaside
# Central Bay Street
# Christie
# Cedarbrae
# Hillcrest Village
# Bathurst Manor, Downsview North, Wilson Heights
# Thorncliffe Park
# Adelaide, King, Richmond
# Dovercourt Village, Dufferin
# Scarborough Village
# Fairview, Henry Farm, Oriole
# Northwood Park, York University
# East Toronto
# Harbourfront East, Toronto Islands, Union Station
# Little Portugal, Trinity
# East Birchmount Park, Ionview, Kennedy Park
# Bayview Village
# CFB Toronto, Downsview East
# The Danforth West, Riverdale
# Design Exchange, Toronto Dominion Centre
# Brockton, Exhibition Place, Parkdale Village
# Clairlea, Golden Mile, Oakridge
# Silver Hills, York Mills
# Downsview West
# The Beaches West, India Bazaar
# Commerce Court, Victoria Hotel
# Downsview, North Park, Upwood Park
# Humber Summit
# Cliffcrest, Cliffside, Scarborough Village West
# Newtonbrook, Willowdale
# Downsview Central
# Studio District
# Bedford Park, Lawrence Manor East
# Del Ray, Keelesdale, Mount Dennis, Silverthorn
# Emery, Humberlea
# Birch Cliff, Cliffside West
# Willowdale South
# Downsview Northwest
# Lawrence Park
# Roselawn
# The Junction North, Runnymede
# Weston
# Dorset Park, Scarborough Town Centre, Wexford Heights
# York Mills West
# Davisville North
# Forest Hill North, Forest Hill West
# High Park, The Junction South
# Westmount
# Maryvale, Wexford
# Willowdale West
# North Toronto West
# The Annex, North Midtown, Yorkville
# Parkdale, Roncesvalles
# Canada Post Gateway Processing Centre
# Kingsview Village, Martin Grove Gardens, Richview Gardens, St. Phillips
# Agincourt
# Davisville
# Harbord, University of Toronto
# Runnymede, Swansea
# Clarks Corners, Sullivan, Tam O'Shanter
# Moore Park, Summerhill East
# Chinatown, Grange Park, Kensington Market
# Agincourt North, L'Amoreaux East, Milliken, Steeles East
# Deer Park, Forest Hill SE, Rathnelly, South Hill, Summerhill West
# CN Tower, Bathurst Quay, Island airport, Harbourfront West, King and Spadina, Railway Lands, South Niagara
# Humber Bay Shores, Mimico South, New Toronto
# Albion Gardens, Beaumond Heights, Humbergate, Jamestown, Mount Olive, Silverstone, South Steeles, Thistletown
# L'Amoreaux West
# Rosedale
# Stn A PO Boxes 25 The Esplanade
# Alderwood, Long Branch
# Northwest
# Upper Rouge
# Cabbagetown, St. James Town
# First Canadian Place, Underground city
# The Kingsway, Montgomery Road, Old Mill North
# Church and Wellesley
# Business Reply Mail Processing Centre 969 Eastern
# Humber Bay, King's Mill Park, Kingsway Park South East, Mimico NE, Old Mill South, The Queensway East, Royal York South East, Sunnylea
# Kingsway Park South West, Mimico NW, The Queensway West, Royal York South West, South of Bloor
# There are 277 unique categories.

# %%
# one hot encoding
toronto_onehot = pd.get_dummies(toronto_venues[['Venue Category']], prefix="", prefix_sep="")

# add neighborhood column back to dataframe
toronto_onehot['Neighborhood'] = toronto_venues['Neighborhood'] 


toronto_grouped = toronto_onehot.groupby('Neighborhood').mean().reset_index()


num_top_venues = 5

for hood in toronto_grouped['Neighborhood']:
    print("----"+hood+"----")
    temp = toronto_grouped[toronto_grouped['Neighborhood'] == hood].T.reset_index()
    temp.columns = ['venue','freq']
    temp = temp.iloc[1:]
    temp['freq'] = temp['freq'].astype(float)
    temp = temp.round({'freq': 2})
    #print(temp.sort_values('freq', ascending=False).reset_index(drop=True).head(num_top_venues))
    #print('\n')

def return_most_common_venues(row, num_top_venues):
    row_categories = row.iloc[1:]
    row_categories_sorted = row_categories.sort_values(ascending=False)
    
    return row_categories_sorted.index.values[0:num_top_venues]
# Out:
# ----Adelaide, King, Richmond----
# ----Agincourt----
# ----Agincourt North, L'Amoreaux East, Milliken, Steeles East----
# ----Albion Gardens, Beaumond Heights, Humbergate, Jamestown, Mount Olive, Silverstone, South Steeles, Thistletown----
# ----Alderwood, Long Branch----
# ----Bathurst Manor, Downsview North, Wilson Heights----
# ----Bayview Village----
# ----Bedford Park, Lawrence Manor East----
# ----Berczy Park----
# ----Birch Cliff, Cliffside West----
# ----Bloordale Gardens, Eringate, Markland Wood, Old Burnhamthorpe----
# ----Brockton, Exhibition Place, Parkdale Village----
# ----Business Reply Mail Processing Centre 969 Eastern----
# ----CFB Toronto, Downsview East----
# ----CN Tower, Bathurst Quay, Island airport, Harbourfront West, King and Spadina, Railway Lands, South Niagara----
# ----Cabbagetown, St. James Town----
# ----Caledonia-Fairbanks----
# ----Canada Post Gateway Processing Centre----
# ----Cedarbrae----
# ----Central Bay Street----
# ----Chinatown, Grange Park, Kensington Market----
# ----Christie----
# ----Church and Wellesley----
# ----Clairlea, Golden Mile, Oakridge----
# ----Clarks Corners, Sullivan, Tam O'Shanter----
# ----Cliffcrest, Cliffside, Scarborough Village West----
# ----Cloverdale, Islington, Martin Grove, Princess Gardens, West Deane Park----
# ----Commerce Court, Victoria Hotel----
# ----Davisville----
# ----Davisville North----
# ----Deer Park, Forest Hill SE, Rathnelly, South Hill, Summerhill West----
# ----Del Ray, Keelesdale, Mount Dennis, Silverthorn----
# ----Design Exchange, Toronto Dominion Centre----
# ----Don Mills North----
# ----Dorset Park, Scarborough Town Centre, Wexford Heights----
# ----Dovercourt Village, Dufferin----
# ----Downsview Central----
# ----Downsview Northwest----
# ----Downsview West----
# ----Downsview, North Park, Upwood Park----
# ----East Birchmount Park, Ionview, Kennedy Park----
# ----East Toronto----
# ----Emery, Humberlea----
# ----Fairview, Henry Farm, Oriole----
# ----First Canadian Place, Underground city----
# ----Flemingdon Park, Don Mills South----
# ----Forest Hill North, Forest Hill West----
# ----Glencairn----
# ----Guildwood, Morningside, West Hill----
# ----Harbord, University of Toronto----
# ----Harbourfront East, Toronto Islands, Union Station----
# ----Harbourfront, Regent Park----
# ----High Park, The Junction South----
# ----Highland Creek, Rouge Hill, Port Union----
# ----Hillcrest Village----
# ----Humber Bay Shores, Mimico South, New Toronto----
# ----Humber Bay, King's Mill Park, Kingsway Park South East, Mimico NE, Old Mill South, The Queensway East, Royal York South East, Sunnylea----
# ----Humber Summit----
# ----Humewood-Cedarvale----
# ----Kingsview Village, Martin Grove Gardens, Richview Gardens, St. Phillips----
# ----Kingsway Park South West, Mimico NW, The Queensway West, Royal York South West, South of Bloor----
# ----L'Amoreaux West----
# ----Lawrence Heights, Lawrence Manor----
# ----Lawrence Park----
# ----Leaside----
# ----Little Portugal, Trinity----
# ----Maryvale, Wexford----
# ----Moore Park, Summerhill East----
# ----North Toronto West----
# ----Northwest----
# ----Northwood Park, York University----
# ----Parkdale, Roncesvalles----
# ----Parkwoods----
# ----Queen's Park----
# ----Rosedale----
# ----Roselawn----
# ----Rouge, Malvern----
# ----Runnymede, Swansea----
# ----Ryerson, Garden District----
# ----Scarborough Village----
# ----St. James Town----
# ----Stn A PO Boxes 25 The Esplanade----
# ----Studio District----
# ----The Annex, North Midtown, Yorkville----
# ----The Beaches----
# ----The Beaches West, India Bazaar----
# ----The Danforth West, Riverdale----
# ----The Junction North, Runnymede----
# ----The Kingsway, Montgomery Road, Old Mill North----
# ----Thorncliffe Park----
# ----Victoria Village----
# ----Westmount----
# ----Weston----
# ----Willowdale South----
# ----Willowdale West----
# ----Woburn----
# ----Woodbine Gardens, Parkview Hill----
# ----Woodbine Heights----
# ----York Mills West----

# %% [markdown]
# #### Getting Top 100 venues in each neighborhood

# %%
num_top_venues = 100

indicators = ['st', 'nd', 'rd']

# create columns according to number of top venues
columns = ['Neighborhood']
for ind in np.arange(num_top_venues):
    try:
        columns.append('{}{} Most Common Venue'.format(ind+1, indicators[ind]))
    except:
        columns.append('{}th Most Common Venue'.format(ind+1))

# create a new dataframe
neighborhoods_venues_sorted = pd.DataFrame(columns=columns)
neighborhoods_venues_sorted['Neighborhood'] = toronto_grouped['Neighborhood']

for ind in np.arange(toronto_grouped.shape[0]):
    neighborhoods_venues_sorted.iloc[ind, 1:] = return_most_common_venues(toronto_grouped.iloc[ind, :], num_top_venues)

neighborhoods_venues_sorted.head()
# Out:
#                                         Neighborhood 1st Most Common Venue  \
# 0                           Adelaide, King, Richmond           Coffee Shop
# 1                                          Agincourt                Lounge
# 2  Agincourt North, L'Amoreaux East, Milliken, St...                  Park
# 3  Albion Gardens, Beaumond Heights, Humbergate, ...         Grocery Store
# 4                             Alderwood, Long Branch           Pizza Place
#
#   2nd Most Common Venue 3rd Most Common Venue 4th Most Common Venue  \
# 0                  Café                   Bar            Steakhouse
# 1        Breakfast Spot          Skating Rink        Clothing Store
# 2            Playground           Yoga Studio     Electronics Store
# 3           Pizza Place   Fried Chicken Joint           Coffee Shop
# 4              Pharmacy                   Gym          Skating Rink
#
#   5th Most Common Venue 6th Most Common Venue 7th Most Common Venue  \
# 0        Cosmetics Shop                 Hotel            Restaurant
# 1           Yoga Studio   Empanada Restaurant            Donut Shop
# 2               Dog Run      Doner Restaurant            Donut Shop
# 3        Sandwich Place  Fast Food Restaurant            Beer Store
# 4                   Pub           Coffee Shop    Athletics & Sports
#
#   8th Most Common Venue   9th Most Common Venue  ... 91th Most Common Venue  \
# 0          Burger Joint     American Restaurant  ...            Flea Market
# 1             Drugstore     Dumpling Restaurant  ...       Asian Restaurant
# 2             Drugstore     Dumpling Restaurant  ...       Asian Restaurant
# 3              Pharmacy  Gluten-free Restaurant  ...       Asian Restaurant
# 4        Sandwich Place                    Pool  ...             Baby Store
#
#   92th Most Common Venue 93th Most Common Venue 94th Most Common Venue  \
# 0            Flower Shop                   Food      Food & Drink Shop
# 1    Arts & Crafts Store             Art Museum            Art Gallery
# 2    Arts & Crafts Store             Art Museum            Art Gallery
# 3    Arts & Crafts Store             Art Museum            Art Gallery
# 4          Auto Workshop            College Gym       Asian Restaurant
#
#   95th Most Common Venue 96th Most Common Venue 97th Most Common Venue  \
# 0              Drugstore               Creperie            Yoga Studio
# 1               Aquarium           Antique Shop    American Restaurant
# 2               Aquarium           Antique Shop    American Restaurant
# 3               Aquarium           Antique Shop    American Restaurant
# 4    Arts & Crafts Store             Art Museum            Art Gallery
#
#   98th Most Common Venue 99th Most Common Venue 100th Most Common Venue
# 0           Cocktail Bar        Coworking Space              Baby Store
# 1       Airport Terminal        Airport Service          Airport Lounge
# 2       Airport Terminal        Airport Service          Airport Lounge
# 3       Airport Terminal        Airport Service          Airport Lounge
# 4               Aquarium           Antique Shop     American Restaurant
#
# [5 rows x 101 columns]

# %% [markdown]
# #### Using k-Means to cluster venues into 5 clusters

# %%
# set number of clusters
kclusters = 5

toronto_grouped_clustering = toronto_grouped.drop('Neighborhood', 1)

# run k-means clustering
kmeans = KMeans(n_clusters=kclusters, random_state=0).fit(toronto_grouped_clustering)

# check cluster labels generated for each row in the dataframe
kmeans.labels_[0:10] 

# add clustering labels
neighborhoods_venues_sorted.insert(0, 'Cluster Labels', kmeans.labels_)

toronto_merged = df
toronto_merged.rename(columns = {'Neighbourhood':'Neighborhood'}, inplace = True)


# merge toronto_grouped with toronto_data to add latitude/longitude for each neighborhood
toronto_merged = toronto_merged.join(neighborhoods_venues_sorted.set_index('Neighborhood'), on='Neighborhood')
toronto_merged.head() # check the last columns!
# Out:
#   Postcode           Borough                      Neighborhood   Latitude  \
# 0      M3A        North York                         Parkwoods  43.753259
# 1      M4A        North York                  Victoria Village  43.725882
# 2      M5A  Downtown Toronto         Harbourfront, Regent Park  43.654260
# 3      M6A        North York  Lawrence Heights, Lawrence Manor  43.718518
# 4      M7A      Queen's Park                      Queen's Park  43.662301
#
#    Longitude  Cluster Labels   1st Most Common Venue  \
# 0 -79.329656             0.0       Food & Drink Shop
# 1 -79.315572             1.0   Portuguese Restaurant
# 2 -79.360636             1.0             Coffee Shop
# 3 -79.464763             1.0  Furniture / Home Store
# 4 -79.389494             1.0             Coffee Shop
#
#         2nd Most Common Venue 3rd Most Common Venue 4th Most Common Venue  \
# 0        Fast Food Restaurant                  Park     Electronics Store
# 1  Financial or Legal Service           Coffee Shop          Hockey Arena
# 2                      Bakery                  Park                  Café
# 3              Clothing Store     Accessories Store           Coffee Shop
# 4                        Park                   Gym                 Diner
#
#    ... 91th Most Common Venue 92th Most Common Venue 93th Most Common Venue  \
# 0  ...    Arts & Crafts Store             Art Museum            Art Gallery
# 1  ...     Athletics & Sports       Asian Restaurant    Arts & Crafts Store
# 2  ...       Basketball Court       Baseball Stadium         Baseball Field
# 3  ...        College Stadium       Asian Restaurant    Arts & Crafts Store
# 4  ...               Bus Line          Auto Workshop              BBQ Joint
#
#   94th Most Common Venue 95th Most Common Venue 96th Most Common Venue  \
# 0               Aquarium           Antique Shop    American Restaurant
# 1             Art Museum            Art Gallery               Aquarium
# 2                    Bar             Bagel Shop             Baby Store
# 3             Art Museum            Art Gallery               Aquarium
# 4             Baby Store               Building        Bubble Tea Shop
#
#   97th Most Common Venue 98th Most Common Venue 99th Most Common Venue  \
# 0       Airport Terminal        Airport Service         Airport Lounge
# 1           Antique Shop    American Restaurant       Airport Terminal
# 2          Auto Workshop              Bookstore     Athletics & Sports
# 3           Antique Shop    American Restaurant       Airport Terminal
# 4             Bagel Shop            Bridal Shop                Brewery
#
#   100th Most Common Venue
# 0            Airport Gate
# 1         Airport Service
# 2        Asian Restaurant
# 3         Airport Service
# 4          Breakfast Spot
#
# [5 rows x 106 columns]

# %% [markdown]
# #### Creating map

# %%
# create map
map_clusters = folium.Map(location=[latitude, longitude], zoom_start=11)

# set color scheme for the clusters
x = np.arange(kclusters)
ys = [i + x + (i*x)**2 for i in range(kclusters)]
colors_array = cm.rainbow(np.linspace(0, 1, len(ys)))
rainbow = [colors.rgb2hex(i) for i in colors_array]

# add markers to the map
markers_colors = []
for lat, lon, poi, cluster in zip(toronto_merged['Latitude'], toronto_merged['Longitude'], toronto_merged['Neighborhood'], toronto_merged['Cluster Labels']):
    label = folium.Popup(str(poi) + ' Cluster ' + str(cluster), parse_html=True)
    folium.CircleMarker(
        [lat, lon],
        radius=5,
        popup=label,
        fill=True,
        fill_color=rainbow[cluster-1],
        fill_opacity=0.7).add_to(map_clusters)

map_clusters
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-21-9d5b2e228aa9> in <module>
#      17         popup=label,
#      18         fill=True,
# ---> 19         fill_color=rainbow[cluster-1],
#      20         fill_opacity=0.7).add_to(map_clusters)
#      21
#
# TypeError: list indices must be integers or slices, not float

# %% [markdown]
# #### Examine Clusters

# %%
cluster1 = toronto_merged.loc[toronto_merged['Cluster Labels'] == 1, toronto_merged.columns[[2] + list(range(6, toronto_merged.shape[1]))]]
cluster2 = toronto_merged.loc[toronto_merged['Cluster Labels'] == 2, toronto_merged.columns[[2] + list(range(6, toronto_merged.shape[1]))]]
cluster3 = toronto_merged.loc[toronto_merged['Cluster Labels'] == 3, toronto_merged.columns[[2] + list(range(6, toronto_merged.shape[1]))]]
cluster4 = toronto_merged.loc[toronto_merged['Cluster Labels'] == 4, toronto_merged.columns[[2] + list(range(6, toronto_merged.shape[1]))]]
cluster5 = toronto_merged.loc[toronto_merged['Cluster Labels'] == 5, toronto_merged.columns[[2] + list(range(6, toronto_merged.shape[1]))]]

# %%
cluster1
# Out:
#                                           Neighborhood  \
# 1                                     Victoria Village
# 2                            Harbourfront, Regent Park
# 3                     Lawrence Heights, Lawrence Manor
# 4                                         Queen's Park
# 6                                       Rouge, Malvern
# 7                                      Don Mills North
# 8                      Woodbine Gardens, Parkview Hill
# 9                             Ryerson, Garden District
# 10                                           Glencairn
# 13                    Flemingdon Park, Don Mills South
# 14                                    Woodbine Heights
# 15                                      St. James Town
# 16                                  Humewood-Cedarvale
# 17   Bloordale Gardens, Eringate, Markland Wood, Ol...
# 18                   Guildwood, Morningside, West Hill
# 19                                         The Beaches
# 20                                         Berczy Park
# 22                                              Woburn
# 23                                             Leaside
# 24                                  Central Bay Street
# 25                                            Christie
# 26                                           Cedarbrae
# 27                                   Hillcrest Village
# 28     Bathurst Manor, Downsview North, Wilson Heights
# 29                                    Thorncliffe Park
# 30                            Adelaide, King, Richmond
# 31                        Dovercourt Village, Dufferin
# 32                                 Scarborough Village
# 33                        Fairview, Henry Farm, Oriole
# 34                     Northwood Park, York University
# ..                                                 ...
# 68                 Forest Hill North, Forest Hill West
# 69                       High Park, The Junction South
# 70                                           Westmount
# 71                                   Maryvale, Wexford
# 72                                     Willowdale West
# 73                                  North Toronto West
# 74                 The Annex, North Midtown, Yorkville
# 75                              Parkdale, Roncesvalles
# 76               Canada Post Gateway Processing Centre
# 77   Kingsview Village, Martin Grove Gardens, Richv...
# 78                                           Agincourt
# 79                                          Davisville
# 80                      Harbord, University of Toronto
# 81                                  Runnymede, Swansea
# 82             Clarks Corners, Sullivan, Tam O'Shanter
# 84           Chinatown, Grange Park, Kensington Market
# 86   Deer Park, Forest Hill SE, Rathnelly, South Hi...
# 87   CN Tower, Bathurst Quay, Island airport, Harbo...
# 88        Humber Bay Shores, Mimico South, New Toronto
# 89   Albion Gardens, Beaumond Heights, Humbergate, ...
# 90                                     L'Amoreaux West
# 92                     Stn A PO Boxes 25 The Esplanade
# 93                              Alderwood, Long Branch
# 94                                           Northwest
# 96                         Cabbagetown, St. James Town
# 97              First Canadian Place, Underground city
# 99                                Church and Wellesley
# 100  Business Reply Mail Processing Centre 969 Eastern
# 101  Humber Bay, King's Mill Park, Kingsway Park So...
# 102  Kingsway Park South West, Mimico NW, The Queen...
#
#       1st Most Common Venue          2nd Most Common Venue  \
# 1     Portuguese Restaurant     Financial or Legal Service
# 2               Coffee Shop                         Bakery
# 3    Furniture / Home Store                 Clothing Store
# 4               Coffee Shop                           Park
# 6      Fast Food Restaurant                    Yoga Studio
# 7      Caribbean Restaurant            Japanese Restaurant
# 8               Pizza Place           Fast Food Restaurant
# 9            Clothing Store                    Coffee Shop
# 10              Pizza Place                           Park
# 13                      Gym                    Coffee Shop
# 14             Skating Rink                       Pharmacy
# 15              Coffee Shop                           Café
# 16                    Trail                          Field
# 17                 Pharmacy              Convenience Store
# 18           Medical Center                 Breakfast Spot
# 19                    Trail              Health Food Store
# 20              Coffee Shop                   Cocktail Bar
# 22              Coffee Shop              Korean Restaurant
# 23              Coffee Shop            Sporting Goods Shop
# 24              Coffee Shop                           Café
# 25                     Café                  Grocery Store
# 26     Caribbean Restaurant               Hakka Restaurant
# 27                  Dog Run             Athletics & Sports
# 28              Coffee Shop      Middle Eastern Restaurant
# 29        Indian Restaurant                   Burger Joint
# 30              Coffee Shop                           Café
# 31                 Pharmacy                         Bakery
# 32               Playground              Convenience Store
# 33           Clothing Store                    Coffee Shop
# 34   Furniture / Home Store                  Metro Station
# ..                      ...                            ...
# 68                    Trail               Sushi Restaurant
# 69                     Café             Mexican Restaurant
# 70              Pizza Place                    Coffee Shop
# 71           Breakfast Spot                     Smoke Shop
# 72              Pizza Place                   Home Service
# 73      Sporting Goods Shop                 Clothing Store
# 74                     Café                    Coffee Shop
# 75           Breakfast Spot                      Gift Shop
# 76                    Hotel                    Coffee Shop
# 77              Pizza Place                           Park
# 78                   Lounge                 Breakfast Spot
# 79             Dessert Shop                 Sandwich Place
# 80                     Café                            Bar
# 81         Sushi Restaurant                           Café
# 82              Pizza Place           Fast Food Restaurant
# 84                     Café  Vegetarian / Vegan Restaurant
# 86                      Pub                    Coffee Shop
# 87           Airport Lounge                Airport Service
# 88              Coffee Shop                       Pharmacy
# 89            Grocery Store                    Pizza Place
# 90     Fast Food Restaurant             Chinese Restaurant
# 92              Coffee Shop                     Restaurant
# 93              Pizza Place                       Pharmacy
# 94            Moving Target            Rental Car Location
# 96              Coffee Shop                           Café
# 97              Coffee Shop                           Café
# 99              Coffee Shop            Japanese Restaurant
# 100      Light Rail Station           Fast Food Restaurant
# 101          Baseball Field                           Pool
# 102    Fast Food Restaurant         Thrift / Vintage Store
#
#          3rd Most Common Venue        4th Most Common Venue  \
# 1                  Coffee Shop                 Hockey Arena
# 2                         Park                         Café
# 3            Accessories Store                  Coffee Shop
# 4                          Gym                        Diner
# 6            Electronics Store                      Dog Run
# 7         Gym / Fitness Center                         Café
# 8                     Pharmacy                    Gastropub
# 9                         Café    Middle Eastern Restaurant
# 10         Japanese Restaurant                          Pub
# 13                  Beer Store             Asian Restaurant
# 14                 Curling Ice                         Park
# 15                       Hotel                   Restaurant
# 16                  Playground                 Hockey Arena
# 17                        Café               Shopping Plaza
# 18         Rental Car Location           Mexican Restaurant
# 19                         Pub                  Yoga Studio
# 20                      Bakery           Seafood Restaurant
# 22           Indian Restaurant                  Yoga Studio
# 23            Sushi Restaurant                 Burger Joint
# 24          Italian Restaurant    Middle Eastern Restaurant
# 25                        Park                  Coffee Shop
# 26                      Bakery                         Bank
# 27    Mediterranean Restaurant                         Pool
# 28          Frozen Yogurt Shop           Chinese Restaurant
# 29                 Yoga Studio                         Bank
# 30                         Bar                   Steakhouse
# 31                 Supermarket    Middle Eastern Restaurant
# 32                 Yoga Studio            Electronics Store
# 33        Fast Food Restaurant                Women's Store
# 34                         Bar         Caribbean Restaurant
# ..                         ...                          ...
# 68          Mexican Restaurant                Jewelry Store
# 69                        Park              Thai Restaurant
# 70   Middle Eastern Restaurant           Chinese Restaurant
# 71                      Bakery    Middle Eastern Restaurant
# 72                 Coffee Shop               Discount Store
# 73                 Coffee Shop                         Café
# 74              Sandwich Place                  Pizza Place
# 75                Dessert Shop  Eastern European Restaurant
# 76         Fried Chicken Joint         Gym / Fitness Center
# 77           Mobile Phone Shop                     Bus Line
# 78                Skating Rink               Clothing Store
# 79                 Coffee Shop                  Pizza Place
# 80         Japanese Restaurant                    Bookstore
# 81                 Coffee Shop           Italian Restaurant
# 82         Fried Chicken Joint                         Bank
# 84                         Bar          Dumpling Restaurant
# 86     Health & Beauty Service          American Restaurant
# 87            Airport Terminal              Harbor / Marina
# 88                      Bakery          Fried Chicken Joint
# 89         Fried Chicken Joint                  Coffee Shop
# 90         American Restaurant               Breakfast Spot
# 92                        Café           Italian Restaurant
# 93                         Gym                 Skating Rink
# 94                         Bar                    Drugstore
# 96                  Restaurant           Italian Restaurant
# 97                       Hotel                   Restaurant
# 99                     Gay Bar             Sushi Restaurant
# 100                     Garden                   Comic Shop
# 101                Yoga Studio  Eastern European Restaurant
# 102                     Bakery               Discount Store
#
#         5th Most Common Venue        6th Most Common Venue  \
# 1                Intersection                  Pizza Place
# 2        Gym / Fitness Center           Mexican Restaurant
# 3         Sporting Goods Shop           Miscellaneous Shop
# 4          Persian Restaurant           Seafood Restaurant
# 6            Doner Restaurant                   Donut Shop
# 7            Basketball Court  Eastern European Restaurant
# 8              Breakfast Spot                         Bank
# 9              Cosmetics Shop                      Theater
# 10                Yoga Studio          Dumpling Restaurant
# 13        Sporting Goods Shop               Sandwich Place
# 14                 Beer Store                  Video Store
# 15         Italian Restaurant                     Beer Bar
# 16          Electronics Store                      Dog Run
# 17                 Beer Store                  Coffee Shop
# 18          Electronics Store                 Intersection
# 19                    Dog Run             Doner Restaurant
# 20                Cheese Shop               Farmers Market
# 22           Doner Restaurant                   Donut Shop
# 23     Furniture / Home Store                          Gym
# 24             Sandwich Place               Ice Cream Shop
# 25         Italian Restaurant                        Diner
# 26         Athletics & Sports              Thai Restaurant
# 27                Golf Course            Electronics Store
# 28              Deli / Bodega                        Diner
# 29              Grocery Store                 Liquor Store
# 30             Cosmetics Shop                        Hotel
# 31                Music Venue                         Park
# 32                    Dog Run             Doner Restaurant
# 33        Japanese Restaurant             Toy / Game Store
# 34                Coffee Shop           Falafel Restaurant
# ..                        ...                          ...
# 68                Yoga Studio             Doner Restaurant
# 69       Fast Food Restaurant                    Bookstore
# 70             Sandwich Place                 Intersection
# 71                Yoga Studio            Electronics Store
# 72                    Butcher                     Pharmacy
# 73                 Restaurant          Rental Car Location
# 74              Metro Station                    BBQ Joint
# 75                        Bar                         Bank
# 76   Mediterranean Restaurant                Burrito Place
# 77        Dumpling Restaurant                      Dog Run
# 78                Yoga Studio          Empanada Restaurant
# 79           Sushi Restaurant                         Café
# 80                 Restaurant                       Bakery
# 81          Electronics Store                          Bar
# 82         Italian Restaurant           Chinese Restaurant
# 84         Chinese Restaurant           Mexican Restaurant
# 86         Light Rail Station                   Sports Bar
# 87                        Bar                        Plane
# 88                Flower Shop                 Liquor Store
# 89             Sandwich Place         Fast Food Restaurant
# 90             Sandwich Place       Thrift / Vintage Store
# 92                   Beer Bar                 Cocktail Bar
# 93                        Pub                  Coffee Shop
# 94                Yoga Studio               Discount Store
# 96                     Bakery                          Pub
# 97                 Steakhouse           Seafood Restaurant
# 99                 Restaurant                         Café
# 100               Pizza Place                   Restaurant
# 101                   Dog Run             Doner Restaurant
# 102             Tanning Salon                Burrito Place
#
#      7th Most Common Venue 8th Most Common Venue        9th Most Common Venue  \
# 1       Falafel Restaurant           Event Space               Farmers Market
# 2                      Pub        Breakfast Spot                      Theater
# 3         Fraternity House              Boutique        Vietnamese Restaurant
# 4           Sandwich Place          Burger Joint                Burrito Place
# 6                Drugstore   Dumpling Restaurant  Eastern European Restaurant
# 7               Donut Shop             Drugstore          Dumpling Restaurant
# 8             Intersection    Athletics & Sports                    Pet Store
# 9                   Bakery   Sporting Goods Shop                    Bookstore
# 10                 Dog Run      Doner Restaurant                   Donut Shop
# 13     Japanese Restaurant    Italian Restaurant                   Restaurant
# 14          Cosmetics Shop      Doner Restaurant                   Donut Shop
# 15               Gastropub        Cosmetics Shop               Breakfast Spot
# 16        Doner Restaurant            Donut Shop                    Drugstore
# 17            Liquor Store           Pizza Place                         Park
# 18                     Spa           Pizza Place                  Event Space
# 19              Donut Shop             Drugstore          Dumpling Restaurant
# 20                    Café            Steakhouse                     Beer Bar
# 22               Drugstore   Dumpling Restaurant  Eastern European Restaurant
# 23             Supermarket            Sports Bar                   Restaurant
# 24            Burger Joint       Bubble Tea Shop           Chinese Restaurant
# 25              Restaurant    Athletics & Sports                    Nightclub
# 26     Fried Chicken Joint   Dumpling Restaurant             Doner Restaurant
# 27        Doner Restaurant            Donut Shop                    Drugstore
# 28             Supermarket        Sandwich Place                   Restaurant
# 29                    Park              Pharmacy                  Pizza Place
# 30              Restaurant          Burger Joint          American Restaurant
# 31             Pizza Place           Coffee Shop                         Café
# 32              Donut Shop             Drugstore          Dumpling Restaurant
# 33              Food Court            Shoe Store                       Bakery
# 34          Massage Studio           Event Space         Ethiopian Restaurant
# ..                     ...                   ...                          ...
# 68              Donut Shop             Drugstore          Dumpling Restaurant
# 69             Flea Market             Speakeasy    Cajun / Creole Restaurant
# 70                 Dog Run      Doner Restaurant                   Donut Shop
# 71              Donut Shop             Drugstore          Dumpling Restaurant
# 72           Grocery Store          Gourmet Shop           Falafel Restaurant
# 73                   Diner          Dessert Shop           Salon / Barbershop
# 74        Asian Restaurant     Indian Restaurant                          Pub
# 75      Italian Restaurant               Dog Run                   Restaurant
# 76     American Restaurant        Sandwich Place    Middle Eastern Restaurant
# 77        Doner Restaurant            Donut Shop                    Drugstore
# 78              Donut Shop             Drugstore          Dumpling Restaurant
# 79      Italian Restaurant                   Gym                        Diner
# 80            Noodle House           Flower Shop           Italian Restaurant
# 81                    Food     Fish & Chips Shop    Latin American Restaurant
# 82         Thai Restaurant          Noodle House            Electronics Store
# 84   Vietnamese Restaurant                Bakery                  Coffee Shop
# 86              Restaurant           Supermarket             Sushi Restaurant
# 87             Coffee Shop      Sculpture Garden                Boat or Ferry
# 88    Fast Food Restaurant    Mexican Restaurant                  Pizza Place
# 89              Beer Store              Pharmacy       Gluten-free Restaurant
# 90             Coffee Shop          Noodle House                     Pharmacy
# 92                   Hotel    Seafood Restaurant                          Pub
# 93      Athletics & Sports        Sandwich Place                         Pool
# 94        Doner Restaurant            Donut Shop          Dumpling Restaurant
# 96             Pizza Place             Pet Store               Breakfast Spot
# 97                     Bar   American Restaurant                    Gastropub
# 99             Men's Store          Dance Studio                    Gastropub
# 100          Burrito Place               Brewery                   Skate Park
# 101             Donut Shop             Drugstore          Dumpling Restaurant
# 102            Flower Shop        Sandwich Place                 Burger Joint
#
#      ...      91th Most Common Venue   92th Most Common Venue  \
# 1    ...          Athletics & Sports         Asian Restaurant
# 2    ...            Basketball Court         Baseball Stadium
# 3    ...             College Stadium         Asian Restaurant
# 4    ...                    Bus Line            Auto Workshop
# 6    ...         Arts & Crafts Store               Art Museum
# 7    ...         Arts & Crafts Store               Art Museum
# 8    ...               Boat or Ferry         Asian Restaurant
# 9    ...              Discount Store                 Festival
# 10   ...          Athletics & Sports         Asian Restaurant
# 13   ...                  Baby Store                BBQ Joint
# 14   ...          Athletics & Sports         Asian Restaurant
# 15   ...                   Drugstore              Yoga Studio
# 16   ...            Asian Restaurant      Arts & Crafts Store
# 17   ...          Athletics & Sports                   Bistro
# 18   ...               Auto Workshop       Athletics & Sports
# 19   ...            Asian Restaurant      Arts & Crafts Store
# 20   ...                   Bookstore            Boat or Ferry
# 22   ...            Asian Restaurant      Arts & Crafts Store
# 23   ...            Baseball Stadium           Baseball Field
# 24   ...  Financial or Legal Service      Filipino Restaurant
# 25   ...               Boat or Ferry         Asian Restaurant
# 26   ...            Asian Restaurant      Arts & Crafts Store
# 27   ...            Asian Restaurant      Arts & Crafts Store
# 28   ...                  Bagel Shop               Baby Store
# 29   ...                  Beer Store                 Beer Bar
# 30   ...                 Flea Market              Flower Shop
# 31   ...                  Beer Store                 Beer Bar
# 32   ...         Arts & Crafts Store               Art Museum
# 33   ...               Auto Workshop       Belgian Restaurant
# 34   ...            Asian Restaurant      Arts & Crafts Store
# ..   ...                         ...                      ...
# 68   ...          Athletics & Sports         Asian Restaurant
# 69   ...                  Baby Store                BBQ Joint
# 70   ...                   Bike Shop         Asian Restaurant
# 71   ...            Asian Restaurant      Arts & Crafts Store
# 72   ...            Asian Restaurant      Arts & Crafts Store
# 73   ...                  Bagel Shop               Baby Store
# 74   ...                         Bar                     Bank
# 75   ...     Comfort Food Restaurant         Asian Restaurant
# 76   ...                      Bistro       Athletics & Sports
# 77   ...            Asian Restaurant      Arts & Crafts Store
# 78   ...            Asian Restaurant      Arts & Crafts Store
# 79   ...                        Bank                   Bakery
# 80   ...              Baseball Field                     Bank
# 81   ...                      Bakery               Bagel Shop
# 82   ...                      Bistro         Asian Restaurant
# 84   ...           Electronics Store                 Creperie
# 86   ...                      Bakery               Baby Store
# 87   ...              Baseball Field                   Bakery
# 88   ...                      Bistro                Bike Shop
# 89   ...            Asian Restaurant      Arts & Crafts Store
# 90   ...               Auto Workshop          College Stadium
# 92   ...                Airport Gate           Airport Lounge
# 93   ...                  Baby Store            Auto Workshop
# 94   ...            Asian Restaurant      Arts & Crafts Store
# 96   ...                 Curling Ice          Coworking Space
# 97   ...         Empanada Restaurant  Fruit & Vegetable Store
# 99   ...                       Field                 Festival
# 100  ...                  Baby Store                BBQ Joint
# 101  ...         Arts & Crafts Store               Art Museum
# 102  ...                   BBQ Joint       Athletics & Sports
#
#           93th Most Common Venue 94th Most Common Venue  \
# 1            Arts & Crafts Store             Art Museum
# 2                 Baseball Field                    Bar
# 3            Arts & Crafts Store             Art Museum
# 4                      BBQ Joint             Baby Store
# 6                    Art Gallery               Aquarium
# 7                    Art Gallery               Aquarium
# 8            Arts & Crafts Store             Art Museum
# 9                 Farmers Market     Falafel Restaurant
# 10           Arts & Crafts Store             Art Museum
# 13                 Auto Workshop     Athletics & Sports
# 14           Arts & Crafts Store             Art Museum
# 15         College Arts Building        Coworking Space
# 16                    Art Museum            Art Gallery
# 17              Asian Restaurant    Arts & Crafts Store
# 18              Asian Restaurant    Arts & Crafts Store
# 19                    Art Museum            Art Gallery
# 20                     Bike Shop             Beer Store
# 22                    Art Museum            Art Gallery
# 23                           Bar                 Bakery
# 24            Airport Food Court                  Field
# 25           Arts & Crafts Store             Art Museum
# 26                    Art Museum            Art Gallery
# 27                    Art Museum            Art Gallery
# 28                     BBQ Joint          Auto Workshop
# 29               Bed & Breakfast                  Beach
# 30                          Food      Food & Drink Shop
# 31               Bed & Breakfast     Basketball Stadium
# 32                   Art Gallery               Aquarium
# 33                    Beer Store               Beer Bar
# 34                    Art Museum            Art Gallery
# ..                           ...                    ...
# 68           Arts & Crafts Store             Art Museum
# 69                 Auto Workshop     Athletics & Sports
# 70           Arts & Crafts Store             Art Museum
# 71                    Art Museum            Art Gallery
# 72                    Art Museum            Art Gallery
# 73                     BBQ Joint          Auto Workshop
# 74                        Bakery             Bagel Shop
# 75           Arts & Crafts Store             Art Museum
# 76              Asian Restaurant    Arts & Crafts Store
# 77                    Art Museum            Art Gallery
# 78                    Art Museum            Art Gallery
# 79                    Bagel Shop             Baby Store
# 80                    Bagel Shop             Baby Store
# 81                    Baby Store              BBQ Joint
# 82           Arts & Crafts Store             Art Museum
# 84                   Yoga Studio         Cosmetics Shop
# 86                     BBQ Joint          Auto Workshop
# 87                       Brewery             Bagel Shop
# 88            Belgian Restaurant             Beer Store
# 89                    Art Museum            Art Gallery
# 90            Athletics & Sports       Asian Restaurant
# 92                    Food Court      Food & Drink Shop
# 93                   College Gym       Asian Restaurant
# 94                    Art Museum            Art Gallery
# 96              Cuban Restaurant               Creperie
# 97   Eastern European Restaurant         Farmers Market
# 99                 Tanning Salon         Farmers Market
# 100           Athletics & Sports       Asian Restaurant
# 101                  Art Gallery               Aquarium
# 102              College Stadium       Asian Restaurant
#
#     95th Most Common Venue      96th Most Common Venue 97th Most Common Venue  \
# 1              Art Gallery                    Aquarium           Antique Shop
# 2               Bagel Shop                  Baby Store          Auto Workshop
# 3              Art Gallery                    Aquarium           Antique Shop
# 4                 Building             Bubble Tea Shop             Bagel Shop
# 6             Antique Shop         American Restaurant       Airport Terminal
# 7             Antique Shop         American Restaurant       Airport Terminal
# 8              Art Gallery                    Aquarium           Antique Shop
# 9              Event Space         Empanada Restaurant      Electronics Store
# 10             Art Gallery                    Aquarium           Antique Shop
# 13     Arts & Crafts Store                  Art Museum            Art Gallery
# 14             Art Gallery                    Aquarium           Antique Shop
# 15           Auto Workshop                      Bistro              Bike Shop
# 16                Aquarium                Antique Shop    American Restaurant
# 17              Art Museum                 Art Gallery               Aquarium
# 18              Art Museum                 Art Gallery               Aquarium
# 19                Aquarium                Antique Shop    American Restaurant
# 20         Bed & Breakfast            Basketball Court       Baseball Stadium
# 22                Aquarium                Antique Shop    American Restaurant
# 23              Baby Store                   BBQ Joint          Auto Workshop
# 24                Festival                Cupcake Shop     Belgian Restaurant
# 25             Art Gallery                    Aquarium           Antique Shop
# 26                Aquarium                Antique Shop    American Restaurant
# 27                Aquarium                Antique Shop    American Restaurant
# 28      Athletics & Sports            Asian Restaurant    Arts & Crafts Store
# 29      Basketball Stadium            Basketball Court       Baseball Stadium
# 30               Drugstore                    Creperie            Yoga Studio
# 31                Building            Basketball Court    American Restaurant
# 32            Antique Shop         American Restaurant       Airport Terminal
# 33         Bed & Breakfast                       Beach     Basketball Stadium
# 34                Aquarium                Antique Shop    American Restaurant
# ..                     ...                         ...                    ...
# 68             Art Gallery                    Aquarium           Antique Shop
# 69        Asian Restaurant                  Art Museum            Art Gallery
# 70             Art Gallery                    Aquarium           Antique Shop
# 71                Aquarium                Antique Shop    American Restaurant
# 72                Aquarium                Antique Shop    American Restaurant
# 73      Athletics & Sports            Asian Restaurant    Arts & Crafts Store
# 74              Baby Store               Auto Workshop     Athletics & Sports
# 75             Art Gallery                    Aquarium           Antique Shop
# 76              Art Museum                 Art Gallery               Aquarium
# 77                Aquarium                Antique Shop    American Restaurant
# 78                Aquarium                Antique Shop    American Restaurant
# 79               BBQ Joint               Auto Workshop     Athletics & Sports
# 80               BBQ Joint               Auto Workshop       Asian Restaurant
# 81           Auto Workshop          Athletics & Sports       Asian Restaurant
# 82             Art Gallery                    Aquarium           Antique Shop
# 84      Athletics & Sports                      Bistro              Bike Shop
# 86      Athletics & Sports            Asian Restaurant    Arts & Crafts Store
# 87              Baby Store                   BBQ Joint          Auto Workshop
# 88         Bed & Breakfast                  Comic Shop                  Beach
# 89                Aquarium                Antique Shop    American Restaurant
# 90     Arts & Crafts Store                  Art Museum            Art Gallery
# 92                    Food                 Flower Shop            Flea Market
# 93     Arts & Crafts Store                  Art Museum            Art Gallery
# 94                Aquarium                Antique Shop    American Restaurant
# 96              Bagel Shop                 Candy Store           Camera Store
# 97             Yoga Studio  Construction & Landscaping              BBQ Joint
# 99      Falafel Restaurant                 Event Space       Tapas Restaurant
# 100    Arts & Crafts Store                  Art Museum            Art Gallery
# 101           Antique Shop         American Restaurant       Airport Terminal
# 102    Arts & Crafts Store                  Art Museum            Art Gallery
#
#         98th Most Common Venue 99th Most Common Venue  \
# 1          American Restaurant       Airport Terminal
# 2                    Bookstore     Athletics & Sports
# 3          American Restaurant       Airport Terminal
# 4                  Bridal Shop                Brewery
# 6              Airport Service         Airport Lounge
# 7              Airport Service         Airport Lounge
# 8          American Restaurant       Airport Terminal
# 9          Dumpling Restaurant              Drugstore
# 10         American Restaurant       Airport Terminal
# 13                    Aquarium           Antique Shop
# 14         American Restaurant       Airport Terminal
# 15          Belgian Restaurant             Beer Store
# 16            Airport Terminal        Airport Service
# 17                Antique Shop    American Restaurant
# 18                Antique Shop    American Restaurant
# 19            Airport Terminal        Airport Service
# 20              Baseball Field                    Bar
# 22            Airport Terminal        Airport Service
# 23            Asian Restaurant             Comic Shop
# 24                    Creperie               Building
# 25         American Restaurant       Airport Terminal
# 26            Airport Terminal        Airport Service
# 27            Airport Terminal        Airport Service
# 28                  Art Museum            Art Gallery
# 29                Antique Shop         Baseball Field
# 30                Cocktail Bar        Coworking Space
# 31            Baseball Stadium         Baseball Field
# 32             Airport Service         Airport Lounge
# 33            Basketball Court       Baseball Stadium
# 34            Airport Terminal        Airport Service
# ..                         ...                    ...
# 68         American Restaurant       Airport Terminal
# 69                    Aquarium           Antique Shop
# 70         American Restaurant       Airport Terminal
# 71            Airport Terminal        Airport Service
# 72            Airport Terminal        Airport Service
# 73                  Art Museum            Art Gallery
# 74         Arts & Crafts Store             Art Museum
# 75         American Restaurant       Airport Terminal
# 76                Antique Shop       Airport Terminal
# 77            Airport Terminal        Airport Service
# 78            Airport Terminal        Airport Service
# 79            Asian Restaurant    Arts & Crafts Store
# 80               Boat or Ferry    Arts & Crafts Store
# 81         Arts & Crafts Store             Art Museum
# 82         American Restaurant       Airport Terminal
# 84                  Beer Store                  Beach
# 86                  Art Museum            Art Gallery
# 87          Athletics & Sports       Asian Restaurant
# 88          Basketball Stadium       Basketball Court
# 89            Airport Terminal        Airport Service
# 90                    Aquarium           Antique Shop
# 92             Airport Service      Fish & Chips Shop
# 93                    Aquarium           Antique Shop
# 94            Airport Terminal        Airport Service
# 96   Cajun / Creole Restaurant                    Bar
# 97                   Bike Shop     Belgian Restaurant
# 99         Empanada Restaurant      Electronics Store
# 100                   Aquarium           Antique Shop
# 101            Airport Service         Airport Lounge
# 102                   Aquarium           Antique Shop
#
#          100th Most Common Venue
# 1                Airport Service
# 2               Asian Restaurant
# 3                Airport Service
# 4                 Breakfast Spot
# 6                   Airport Gate
# 7                   Airport Gate
# 8                Airport Service
# 9                     Donut Shop
# 10               Airport Service
# 13           American Restaurant
# 14               Airport Service
# 15               Bed & Breakfast
# 16                Airport Lounge
# 17              Airport Terminal
# 18              Airport Terminal
# 19                Airport Lounge
# 20                          Bank
# 22                Airport Lounge
# 23           Arts & Crafts Store
# 24                   Candy Store
# 25               Airport Service
# 26                Airport Lounge
# 27                Airport Lounge
# 28                      Aquarium
# 29                           Bar
# 30                    Baby Store
# 31                  Antique Shop
# 32                  Airport Gate
# 33                           Bar
# 34                Airport Lounge
# ..                           ...
# 68               Airport Service
# 69           American Restaurant
# 70               Airport Service
# 71                Airport Lounge
# 72                Airport Lounge
# 73                      Aquarium
# 74                   Art Gallery
# 75               Airport Service
# 76               Airport Service
# 77                Airport Lounge
# 78                Airport Lounge
# 79                    Art Museum
# 80                    Art Museum
# 81                   Art Gallery
# 82               Airport Service
# 84            Basketball Stadium
# 86                      Aquarium
# 87           Arts & Crafts Store
# 88              Baseball Stadium
# 89                Airport Lounge
# 90              Airport Terminal
# 92    Financial or Legal Service
# 93           American Restaurant
# 94                Airport Lounge
# 96                   Bus Station
# 97                    Beer Store
# 99   Eastern European Restaurant
# 100          American Restaurant
# 101                 Airport Gate
# 102          American Restaurant
#
# [85 rows x 101 columns]

# %%
cluster2
# Out:
#      Neighborhood 1st Most Common Venue 2nd Most Common Venue  \
# 50  Humber Summit   Empanada Restaurant     Electronics Store
#
#    3rd Most Common Venue 4th Most Common Venue 5th Most Common Venue  \
# 50               Dog Run      Doner Restaurant            Donut Shop
#
#    6th Most Common Venue 7th Most Common Venue        8th Most Common Venue  \
# 50             Drugstore   Dumpling Restaurant  Eastern European Restaurant
#
#    9th Most Common Venue  ... 91th Most Common Venue 92th Most Common Venue  \
# 50           Yoga Studio  ...    Arts & Crafts Store             Art Museum
#
#    93th Most Common Venue 94th Most Common Venue 95th Most Common Venue  \
# 50            Art Gallery               Aquarium           Antique Shop
#
#    96th Most Common Venue 97th Most Common Venue 98th Most Common Venue  \
# 50    American Restaurant       Airport Terminal        Airport Service
#
#    99th Most Common Venue 100th Most Common Venue
# 50         Airport Lounge            Airport Gate
#
# [1 rows x 101 columns]

# %%
cluster3
# Out:
#                                          Neighborhood 1st Most Common Venue  \
# 11  Cloverdale, Islington, Martin Grove, Princess ...                  Bank
#
#    2nd Most Common Venue 3rd Most Common Venue 4th Most Common Venue  \
# 11           Yoga Studio   Empanada Restaurant            Donut Shop
#
#    5th Most Common Venue 6th Most Common Venue        7th Most Common Venue  \
# 11             Drugstore   Dumpling Restaurant  Eastern European Restaurant
#
#    8th Most Common Venue 9th Most Common Venue  ... 91th Most Common Venue  \
# 11     Electronics Store  Ethiopian Restaurant  ...    Arts & Crafts Store
#
#    92th Most Common Venue 93th Most Common Venue 94th Most Common Venue  \
# 11             Art Museum            Art Gallery               Aquarium
#
#    95th Most Common Venue 96th Most Common Venue 97th Most Common Venue  \
# 11           Antique Shop    American Restaurant       Airport Terminal
#
#    98th Most Common Venue 99th Most Common Venue 100th Most Common Venue
# 11        Airport Service         Airport Lounge            Airport Gate
#
# [1 rows x 101 columns]

# %%
cluster4
# Out:
#                               Neighborhood 1st Most Common Venue  \
# 12  Highland Creek, Rouge Hill, Port Union                   Bar
#
#    2nd Most Common Venue 3rd Most Common Venue 4th Most Common Venue  \
# 12           Yoga Studio   Empanada Restaurant            Donut Shop
#
#    5th Most Common Venue 6th Most Common Venue        7th Most Common Venue  \
# 12             Drugstore   Dumpling Restaurant  Eastern European Restaurant
#
#    8th Most Common Venue 9th Most Common Venue  ... 91th Most Common Venue  \
# 12     Electronics Store  Ethiopian Restaurant  ...    Arts & Crafts Store
#
#    92th Most Common Venue 93th Most Common Venue 94th Most Common Venue  \
# 12             Art Museum            Art Gallery               Aquarium
#
#    95th Most Common Venue 96th Most Common Venue 97th Most Common Venue  \
# 12           Antique Shop    American Restaurant       Airport Terminal
#
#    98th Most Common Venue 99th Most Common Venue 100th Most Common Venue
# 12        Airport Service         Airport Lounge            Airport Gate
#
# [1 rows x 101 columns]

# %%
cluster5
# Out:
# Empty DataFrame
# Columns: [Neighborhood, 1st Most Common Venue, 2nd Most Common Venue, 3rd Most Common Venue, 4th Most Common Venue, 5th Most Common Venue, 6th Most Common Venue, 7th Most Common Venue, 8th Most Common Venue, 9th Most Common Venue, 10th Most Common Venue, 11th Most Common Venue, 12th Most Common Venue, 13th Most Common Venue, 14th Most Common Venue, 15th Most Common Venue, 16th Most Common Venue, 17th Most Common Venue, 18th Most Common Venue, 19th Most Common Venue, 20th Most Common Venue, 21th Most Common Venue, 22th Most Common Venue, 23th Most Common Venue, 24th Most Common Venue, 25th Most Common Venue, 26th Most Common Venue, 27th Most Common Venue, 28th Most Common Venue, 29th Most Common Venue, 30th Most Common Venue, 31th Most Common Venue, 32th Most Common Venue, 33th Most Common Venue, 34th Most Common Venue, 35th Most Common Venue, 36th Most Common Venue, 37th Most Common Venue, 38th Most Common Venue, 39th Most Common Venue, 40th Most Common Venue, 41th Most Common Venue, 42th Most Common Venue, 43th Most Common Venue, 44th Most Common Venue, 45th Most Common Venue, 46th Most Common Venue, 47th Most Common Venue, 48th Most Common Venue, 49th Most Common Venue, 50th Most Common Venue, 51th Most Common Venue, 52th Most Common Venue, 53th Most Common Venue, 54th Most Common Venue, 55th Most Common Venue, 56th Most Common Venue, 57th Most Common Venue, 58th Most Common Venue, 59th Most Common Venue, 60th Most Common Venue, 61th Most Common Venue, 62th Most Common Venue, 63th Most Common Venue, 64th Most Common Venue, 65th Most Common Venue, 66th Most Common Venue, 67th Most Common Venue, 68th Most Common Venue, 69th Most Common Venue, 70th Most Common Venue, 71th Most Common Venue, 72th Most Common Venue, 73th Most Common Venue, 74th Most Common Venue, 75th Most Common Venue, 76th Most Common Venue, 77th Most Common Venue, 78th Most Common Venue, 79th Most Common Venue, 80th Most Common Venue, 81th Most Common Venue, 82th Most Common Venue, 83th Most Common Venue, 84th Most Common Venue, 85th Most Common Venue, 86th Most Common Venue, 87th Most Common Venue, 88th Most Common Venue, 89th Most Common Venue, 90th Most Common Venue, 91th Most Common Venue, 92th Most Common Venue, 93th Most Common Venue, 94th Most Common Venue, 95th Most Common Venue, 96th Most Common Venue, 97th Most Common Venue, 98th Most Common Venue, 99th Most Common Venue, ...]
# Index: []
#
# [0 rows x 101 columns]
