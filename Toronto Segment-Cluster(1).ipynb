# %% [markdown]
# ## Part I. Scraping Table From Wiki Page

# %%
import pandas as pd
import numpy as np


#reading html page for table
tables = pd.read_html("https://en.wikipedia.org/wiki/List_of_postal_codes_of_Canada:_M", header = 0)


table = tables[0]                      #identifying the table 
df = pd.DataFrame(table)               #converting table to dataframe
df = df[df.Borough != 'Not assigned']  #dropping records where borough is not assigned
df.sort_values('Postcode')             #sorting to see multiple neighborhoods with the same postcode


#identifying neighborhoods with the same postcode and convert to a list
lst = []
nbhds = []
for pc in df['Postcode']:
    lst = df.loc[df['Postcode'] == pc]['Neighbourhood'].tolist()
    nbhds.append(', '.join(lst))


df['Neighbourhood'] = nbhds            #listing neighborhoods with the same postcode together
df.loc[df['Neighbourhood'] == 'Not assigned', 'Neighbourhood'] = df['Borough'] #assign "Not assigned" neighborhoods the same name as their borough
df.drop_duplicates(inplace = True)     #drop dupicate rows
df = df.reset_index(drop = True)       #reset index
df.head(10)                            #display first 10 rows table
# Out:
#   Postcode           Borough                     Neighbourhood
# 0      M3A        North York                         Parkwoods
# 1      M4A        North York                  Victoria Village
# 2      M5A  Downtown Toronto         Harbourfront, Regent Park
# 3      M6A        North York  Lawrence Heights, Lawrence Manor
# 4      M7A      Queen's Park                      Queen's Park
# 5      M9A         Etobicoke                  Islington Avenue
# 6      M1B       Scarborough                    Rouge, Malvern
# 7      M3B        North York                   Don Mills North
# 8      M4B         East York   Woodbine Gardens, Parkview Hill
# 9      M5B  Downtown Toronto          Ryerson, Garden District

# %% [markdown]
# ## Part II. Geographical Coordinates For Each Neighborhood

# %%
df_geospatial = pd.read_csv('https://cocl.us/Geospatial_data')               #importing csv
df_geospatial.rename(columns = {'Postal Code': 'Postcode'}, inplace = True)  #rename post code column to match with table above
df = df.join(df_geospatial.set_index('Postcode'), on='Postcode')             #join the dataframe on "postcode" to include the geospatial coords
df.head(10)                                                                  #show first 10 rows of new dataframe
# Out:
#   Postcode           Borough                     Neighbourhood   Latitude  \
# 0      M3A        North York                         Parkwoods  43.753259
# 1      M4A        North York                  Victoria Village  43.725882
# 2      M5A  Downtown Toronto         Harbourfront, Regent Park  43.654260
# 3      M6A        North York  Lawrence Heights, Lawrence Manor  43.718518
# 4      M7A      Queen's Park                      Queen's Park  43.662301
# 5      M9A         Etobicoke                  Islington Avenue  43.667856
# 6      M1B       Scarborough                    Rouge, Malvern  43.806686
# 7      M3B        North York                   Don Mills North  43.745906
# 8      M4B         East York   Woodbine Gardens, Parkview Hill  43.706397
# 9      M5B  Downtown Toronto          Ryerson, Garden District  43.657162
#
#    Longitude
# 0 -79.329656
# 1 -79.315572
# 2 -79.360636
# 3 -79.464763
# 4 -79.389494
# 5 -79.532242
# 6 -79.194353
# 7 -79.352188
# 8 -79.309937
# 9 -79.378937

# %% [markdown]
# ## Part III. Explore/Cluster Toronto Data

# %%
# !conda install -c conda-forge folium=0.5.0 --yes
# Out:
# Solving environment: done
#
# # All requested packages already installed.

# %%
#import dependencies
import folium 
from geopy.geocoders import Nominatim
import requests
import matplotlib.cm as cm
import matplotlib.colors as colors
from sklearn.cluster import KMeans
import json
from pandas.io.json import json_normalize

# %%
#idenitfy foursquare API credentials
CLIENT_ID = 'ELSG32TONI3DCWBV45RZO5AH5TXQRPEANXTYBZHYD4PBN12G' # your Foursquare ID
CLIENT_SECRET = 'H2XB5ENY1CSCUYOQHNWJIPLJPJ5L2V34A4QP0EA0J4LCVP0I' # your Foursquare Secret
VERSION = '20180605' # Foursquare API version

print('Your credentails:')
print('CLIENT_ID: ' + CLIENT_ID)
print('CLIENT_SECRET:' + CLIENT_SECRET)
# Out:
# Your credentails:
# CLIENT_ID: ELSG32TONI3DCWBV45RZO5AH5TXQRPEANXTYBZHYD4PBN12G
# CLIENT_SECRET:H2XB5ENY1CSCUYOQHNWJIPLJPJ5L2V34A4QP0EA0J4LCVP0I

# %% [markdown]
# #### Getting the geographical coordinates of Toronto

# %%
address = 'Toronto, Ontario, Canada'

geolocator = Nominatim(user_agent="ny_explorer")
location = geolocator.geocode(address)
latitude = location.latitude
longitude = location.longitude
print('The geograpical coordinate of Toronto are {}, {}.'.format(latitude, longitude))
# Out:
# The geograpical coordinate of Toronto are 43.653963, -79.387207.

# %% [markdown]
# #### Creating map of Toronto with Neighborhood names

# %%
map_toronto = folium.Map(location=[latitude, longitude], zoom_start=10)

# add markers to map
for lat, lng, borough, neighborhood in zip(df['Latitude'], df['Longitude'], df['Borough'], df['Neighbourhood']):
    label = '{}, {}'.format(neighborhood, borough)
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
        [lat, lng],
        radius=5,
        popup=label,
        color='blue',
        fill=True,
        fill_color='#3186cc',
        fill_opacity=0.7,
        parse_html=False).add_to(map_toronto)  
    
map_toronto
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# #### Getting Top 100 venues within 5000 meters of Queen's Park

# %%
nbhd = 'Queen\'s Park' 
mask = df['Neighbourhood'].str.contains(nbhd)
nbhd_lat = df.loc[mask, 'Latitude'].iat[0]
nbhd_long = df.loc[mask, 'Longitude'].iat[0]

LIMIT = 100

radius = 5000 
url = 'https://api.foursquare.com/v2/venues/explore?&client_id={}&client_secret={}&v={}&ll={},{}&radius={}&limit={}'.format(
    CLIENT_ID, 
    CLIENT_SECRET, 
    VERSION, 
    nbhd_lat, 
    nbhd_long, 
    radius, 
    LIMIT)

results = requests.get(url).json()
print('The results are for the neighbordhood -', nbhd, 'located at', nbhd_lat, nbhd_long)
# Out:
# The results are for the neighbordhood - Queen's Park located at 43.6623015 -79.3894938

# %%
# function that extracts the category of the venue
def get_category_type(row):
    try:
        categories_list = row['categories']
    except:
        categories_list = row['venue.categories']
        
    if len(categories_list) == 0:
        return None
    else:
        return categories_list[0]['name']

# %% [markdown]
# #### Getting venues nearby Queen's Park

# %%
#create dataframe from results
venues = results['response']['groups'][0]['items']
    
nearby_venues = json_normalize(venues) # flatten JSON

# filter columns
filtered_columns = ['venue.name', 'venue.categories', 'venue.location.lat', 'venue.location.lng']
nearby_venues =nearby_venues.loc[:, filtered_columns]

# filter the category for each row
nearby_venues['venue.categories'] = nearby_venues.apply(get_category_type, axis=1)

# clean columns
nearby_venues.columns = [col.split(".")[-1] for col in nearby_venues.columns]

nearby_venues.head()
# Out:
#                    name      categories        lat        lng
# 0     DanceLifeX Centre    Dance Studio  43.666956 -79.385297
# 1        Jimmy's Coffee     Coffee Shop  43.658421 -79.385613
# 2         Hailed Coffee     Coffee Shop  43.658833 -79.383684
# 3          Banh Mi Boys  Sandwich Place  43.659292 -79.381949
# 4  Royal Ontario Museum          Museum  43.668367 -79.394813

# %%
print('{} venues were returned by Foursquare.'.format(nearby_venues.shape[0]))
# Out:
# 100 venues were returned by Foursquare.

# %% [markdown]
# #### Getting all venues in Toronto

# %%
def getNearbyVenues(names, latitudes, longitudes, radius=500):
    
    venues_list=[]
    for name, lat, lng in zip(names, latitudes, longitudes):
        print(name)
            
        # create the API request URL
        url = 'https://api.foursquare.com/v2/venues/explore?&client_id={}&client_secret={}&v={}&ll={},{}&radius={}&limit={}'.format(
            CLIENT_ID, 
            CLIENT_SECRET, 
            VERSION, 
            lat, 
            lng, 
            radius, 
            LIMIT)
            
        # make the GET request
        results = requests.get(url).json()["response"]['groups'][0]['items']
        
        # return only relevant information for each nearby venue
        venues_list.append([(
            name, 
            lat, 
            lng, 
            v['venue']['name'], 
            v['venue']['location']['lat'], 
            v['venue']['location']['lng'],  
            v['venue']['categories'][0]['name']) for v in results])

    nearby_venues = pd.DataFrame([item for venue_list in venues_list for item in venue_list])
    nearby_venues.columns = ['Neighborhood', 
                  'Neighborhood Latitude', 
                  'Neighborhood Longitude', 
                  'Venue', 
                  'Venue Latitude', 
                  'Venue Longitude', 
                  'Venue Category']
    return(nearby_venues)

# %%
toronto_venues = getNearbyVenues(names=df['Neighbourhood'], latitudes=df['Latitude'],longitudes=df['Longitude'])
print('There are {} unique categories.'.format(len(toronto_venues['Venue Category'].unique())))
# Out:
# Parkwoods
# Victoria Village
# Harbourfront, Regent Park
# Lawrence Heights, Lawrence Manor
# Queen's Park
# Islington Avenue
# Rouge, Malvern
# Don Mills North
# Woodbine Gardens, Parkview Hill
# Ryerson, Garden District
# Glencairn
# Cloverdale, Islington, Martin Grove, Princess Gardens, West Deane Park
# Highland Creek, Rouge Hill, Port Union
# Flemingdon Park, Don Mills South
# Woodbine Heights
# St. James Town
# Humewood-Cedarvale
# Bloordale Gardens, Eringate, Markland Wood, Old Burnhamthorpe
# Guildwood, Morningside, West Hill
# The Beaches
# Berczy Park
# Caledonia-Fairbanks
# Woburn
# Leaside
# Central Bay Street
# Christie
# Cedarbrae
# Hillcrest Village
# Bathurst Manor, Downsview North, Wilson Heights
# Thorncliffe Park
# Adelaide, King, Richmond
# Dovercourt Village, Dufferin
# Scarborough Village
# Fairview, Henry Farm, Oriole
# Northwood Park, York University
# East Toronto
# Harbourfront East, Toronto Islands, Union Station
# Little Portugal, Trinity
# East Birchmount Park, Ionview, Kennedy Park
# Bayview Village
# CFB Toronto, Downsview East
# The Danforth West, Riverdale
# Design Exchange, Toronto Dominion Centre
# Brockton, Exhibition Place, Parkdale Village
# Clairlea, Golden Mile, Oakridge
# Silver Hills, York Mills
# Downsview West
# The Beaches West, India Bazaar
# Commerce Court, Victoria Hotel
# Downsview, North Park, Upwood Park
# Humber Summit
# Cliffcrest, Cliffside, Scarborough Village West
# Newtonbrook, Willowdale
# Downsview Central
# Studio District
# Bedford Park, Lawrence Manor East
# Del Ray, Keelesdale, Mount Dennis, Silverthorn
# Emery, Humberlea
# Birch Cliff, Cliffside West
# Willowdale South
# Downsview Northwest
# Lawrence Park
# Roselawn
# The Junction North, Runnymede
# Weston
# Dorset Park, Scarborough Town Centre, Wexford Heights
# York Mills West
# Davisville North
# Forest Hill North, Forest Hill West
# High Park, The Junction South
# Westmount
# Maryvale, Wexford
# Willowdale West
# North Toronto West
# The Annex, North Midtown, Yorkville
# Parkdale, Roncesvalles
# Canada Post Gateway Processing Centre
# Kingsview Village, Martin Grove Gardens, Richview Gardens, St. Phillips
# Agincourt
# Davisville
# Harbord, University of Toronto
# Runnymede, Swansea
# Clarks Corners, Sullivan, Tam O'Shanter
# Moore Park, Summerhill East
# Chinatown, Grange Park, Kensington Market
# Agincourt North, L'Amoreaux East, Milliken, Steeles East
# Deer Park, Forest Hill SE, Rathnelly, South Hill, Summerhill West
# CN Tower, Bathurst Quay, Island airport, Harbourfront West, King and Spadina, Railway Lands, South Niagara
# Humber Bay Shores, Mimico South, New Toronto
# Albion Gardens, Beaumond Heights, Humbergate, Jamestown, Mount Olive, Silverstone, South Steeles, Thistletown
# L'Amoreaux West
# Rosedale
# Stn A PO Boxes 25 The Esplanade
# Alderwood, Long Branch
# Northwest
# Upper Rouge
# Cabbagetown, St. James Town
# First Canadian Place, Underground city
# The Kingsway, Montgomery Road, Old Mill North
# Church and Wellesley
# Business Reply Mail Processing Centre 969 Eastern
# Humber Bay, King's Mill Park, Kingsway Park South East, Mimico NE, Old Mill South, The Queensway East, Royal York South East, Sunnylea
# Kingsway Park South West, Mimico NW, The Queensway West, Royal York South West, South of Bloor
# There are 274 unique categories.

# %%
# one hot encoding
toronto_onehot = pd.get_dummies(toronto_venues[['Venue Category']], prefix="", prefix_sep="")

# add neighborhood column back to dataframe
toronto_onehot['Neighborhood'] = toronto_venues['Neighborhood'] 


toronto_grouped = toronto_onehot.groupby('Neighborhood').mean().reset_index()


num_top_venues = 5

for hood in toronto_grouped['Neighborhood']:
    print("----"+hood+"----")
    temp = toronto_grouped[toronto_grouped['Neighborhood'] == hood].T.reset_index()
    temp.columns = ['venue','freq']
    temp = temp.iloc[1:]
    temp['freq'] = temp['freq'].astype(float)
    temp = temp.round({'freq': 2})
    #print(temp.sort_values('freq', ascending=False).reset_index(drop=True).head(num_top_venues))
    #print('\n')

def return_most_common_venues(row, num_top_venues):
    row_categories = row.iloc[1:]
    row_categories_sorted = row_categories.sort_values(ascending=False)
    
    return row_categories_sorted.index.values[0:num_top_venues]
# Out:
# ----Adelaide, King, Richmond----
# ----Agincourt----
# ----Agincourt North, L'Amoreaux East, Milliken, Steeles East----
# ----Albion Gardens, Beaumond Heights, Humbergate, Jamestown, Mount Olive, Silverstone, South Steeles, Thistletown----
# ----Alderwood, Long Branch----
# ----Bathurst Manor, Downsview North, Wilson Heights----
# ----Bayview Village----
# ----Bedford Park, Lawrence Manor East----
# ----Berczy Park----
# ----Birch Cliff, Cliffside West----
# ----Bloordale Gardens, Eringate, Markland Wood, Old Burnhamthorpe----
# ----Brockton, Exhibition Place, Parkdale Village----
# ----Business Reply Mail Processing Centre 969 Eastern----
# ----CFB Toronto, Downsview East----
# ----CN Tower, Bathurst Quay, Island airport, Harbourfront West, King and Spadina, Railway Lands, South Niagara----
# ----Cabbagetown, St. James Town----
# ----Caledonia-Fairbanks----
# ----Canada Post Gateway Processing Centre----
# ----Cedarbrae----
# ----Central Bay Street----
# ----Chinatown, Grange Park, Kensington Market----
# ----Christie----
# ----Church and Wellesley----
# ----Clairlea, Golden Mile, Oakridge----
# ----Clarks Corners, Sullivan, Tam O'Shanter----
# ----Cliffcrest, Cliffside, Scarborough Village West----
# ----Cloverdale, Islington, Martin Grove, Princess Gardens, West Deane Park----
# ----Commerce Court, Victoria Hotel----
# ----Davisville----
# ----Davisville North----
# ----Deer Park, Forest Hill SE, Rathnelly, South Hill, Summerhill West----
# ----Del Ray, Keelesdale, Mount Dennis, Silverthorn----
# ----Design Exchange, Toronto Dominion Centre----
# ----Don Mills North----
# ----Dorset Park, Scarborough Town Centre, Wexford Heights----
# ----Dovercourt Village, Dufferin----
# ----Downsview Central----
# ----Downsview Northwest----
# ----Downsview West----
# ----Downsview, North Park, Upwood Park----
# ----East Birchmount Park, Ionview, Kennedy Park----
# ----East Toronto----
# ----Emery, Humberlea----
# ----Fairview, Henry Farm, Oriole----
# ----First Canadian Place, Underground city----
# ----Flemingdon Park, Don Mills South----
# ----Forest Hill North, Forest Hill West----
# ----Glencairn----
# ----Guildwood, Morningside, West Hill----
# ----Harbord, University of Toronto----
# ----Harbourfront East, Toronto Islands, Union Station----
# ----Harbourfront, Regent Park----
# ----High Park, The Junction South----
# ----Highland Creek, Rouge Hill, Port Union----
# ----Hillcrest Village----
# ----Humber Bay Shores, Mimico South, New Toronto----
# ----Humber Bay, King's Mill Park, Kingsway Park South East, Mimico NE, Old Mill South, The Queensway East, Royal York South East, Sunnylea----
# ----Humber Summit----
# ----Humewood-Cedarvale----
# ----Kingsview Village, Martin Grove Gardens, Richview Gardens, St. Phillips----
# ----Kingsway Park South West, Mimico NW, The Queensway West, Royal York South West, South of Bloor----
# ----L'Amoreaux West----
# ----Lawrence Heights, Lawrence Manor----
# ----Lawrence Park----
# ----Leaside----
# ----Little Portugal, Trinity----
# ----Maryvale, Wexford----
# ----Moore Park, Summerhill East----
# ----North Toronto West----
# ----Northwest----
# ----Northwood Park, York University----
# ----Parkdale, Roncesvalles----
# ----Parkwoods----
# ----Queen's Park----
# ----Rosedale----
# ----Roselawn----
# ----Rouge, Malvern----
# ----Runnymede, Swansea----
# ----Ryerson, Garden District----
# ----Scarborough Village----
# ----Silver Hills, York Mills----
# ----St. James Town----
# ----Stn A PO Boxes 25 The Esplanade----
# ----Studio District----
# ----The Annex, North Midtown, Yorkville----
# ----The Beaches----
# ----The Beaches West, India Bazaar----
# ----The Danforth West, Riverdale----
# ----The Junction North, Runnymede----
# ----The Kingsway, Montgomery Road, Old Mill North----
# ----Thorncliffe Park----
# ----Victoria Village----
# ----Westmount----
# ----Weston----
# ----Willowdale South----
# ----Willowdale West----
# ----Woburn----
# ----Woodbine Gardens, Parkview Hill----
# ----Woodbine Heights----
# ----York Mills West----

# %% [markdown]
# #### Getting Top 100 venues in each neighborhood

# %%
num_top_venues = 100

indicators = ['st', 'nd', 'rd']

# create columns according to number of top venues
columns = ['Neighborhood']
for ind in np.arange(num_top_venues):
    try:
        columns.append('{}{} Most Common Venue'.format(ind+1, indicators[ind]))
    except:
        columns.append('{}th Most Common Venue'.format(ind+1))

# create a new dataframe
neighborhoods_venues_sorted = pd.DataFrame(columns=columns)
neighborhoods_venues_sorted['Neighborhood'] = toronto_grouped['Neighborhood']

for ind in np.arange(toronto_grouped.shape[0]):
    neighborhoods_venues_sorted.iloc[ind, 1:] = return_most_common_venues(toronto_grouped.iloc[ind, :], num_top_venues)

neighborhoods_venues_sorted.head()
# Out:
#                                         Neighborhood 1st Most Common Venue  \
# 0                           Adelaide, King, Richmond           Coffee Shop
# 1                                          Agincourt                Lounge
# 2  Agincourt North, L'Amoreaux East, Milliken, St...            Playground
# 3  Albion Gardens, Beaumond Heights, Humbergate, ...         Grocery Store
# 4                             Alderwood, Long Branch           Pizza Place
#
#   2nd Most Common Venue 3rd Most Common Venue 4th Most Common Venue  \
# 0                  Café                   Bar            Steakhouse
# 1        Sandwich Place        Breakfast Spot          Skating Rink
# 2                  Park           Yoga Studio             Drugstore
# 3              Pharmacy   Fried Chicken Joint           Pizza Place
# 4              Pharmacy          Skating Rink           Coffee Shop
#
#   5th Most Common Venue 6th Most Common Venue 7th Most Common Venue  \
# 0   American Restaurant          Burger Joint       Thai Restaurant
# 1    Chinese Restaurant             Drugstore        Discount Store
# 2    Dim Sum Restaurant                 Diner        Discount Store
# 3           Coffee Shop        Sandwich Place            Beer Store
# 4                  Pool                   Pub        Sandwich Place
#
#   8th Most Common Venue   9th Most Common Venue  ... 91th Most Common Venue  \
# 0            Restaurant          Cosmetics Shop  ...      Fish & Chips Shop
# 1               Dog Run        Doner Restaurant  ...       Asian Restaurant
# 2               Dog Run        Doner Restaurant  ...             Art Museum
# 3  Fast Food Restaurant  Gluten-free Restaurant  ...       Asian Restaurant
# 4                   Gym        Airport Terminal  ...                    Bar
#
#   92th Most Common Venue 93th Most Common Venue 94th Most Common Venue  \
# 0            Fish Market            Flea Market            Flower Shop
# 1    Arts & Crafts Store             Art Museum            Art Gallery
# 2            Art Gallery               Aquarium           Antique Shop
# 3    Arts & Crafts Store             Art Museum            Art Gallery
# 4                   Bank                 Bakery             Bagel Shop
#
#   95th Most Common Venue 96th Most Common Venue 97th Most Common Venue  \
# 0                   Food            Yoga Studio           Climbing Gym
# 1               Aquarium           Antique Shop    American Restaurant
# 2    American Restaurant       Airport Terminal        Airport Service
# 3               Aquarium           Antique Shop    American Restaurant
# 4             Baby Store              BBQ Joint          Auto Workshop
#
#   98th Most Common Venue 99th Most Common Venue 100th Most Common Venue
# 0      Convenience Store              Bike Shop              Beer Store
# 1       Airport Terminal        Airport Service          Airport Lounge
# 2         Airport Lounge           Airport Gate      Airport Food Court
# 3       Airport Terminal        Airport Service          Airport Lounge
# 4            Auto Garage     Athletics & Sports        Asian Restaurant
#
# [5 rows x 101 columns]

# %% [markdown]
# #### Using k-Means to cluster venues into 5 clusters

# %%
# set number of clusters
kclusters = 5

toronto_grouped_clustering = toronto_grouped.drop('Neighborhood', 1)

# run k-means clustering
kmeans = KMeans(n_clusters=kclusters, random_state=0).fit(toronto_grouped_clustering)

# check cluster labels generated for each row in the dataframe
kmeans.labels_[0:10] 

# add clustering labels
neighborhoods_venues_sorted.insert(0, 'Cluster Labels', kmeans.labels_)

toronto_merged = df
toronto_merged.rename(columns = {'Neighbourhood':'Neighborhood'}, inplace = True)


# merge toronto_grouped with toronto_data to add latitude/longitude for each neighborhood
toronto_merged = toronto_merged.join(neighborhoods_venues_sorted.set_index('Neighborhood'), on='Neighborhood')
toronto_merged.head() # check the last columns!
# Out:
#   Postcode           Borough                      Neighborhood   Latitude  \
# 0      M3A        North York                         Parkwoods  43.753259
# 1      M4A        North York                  Victoria Village  43.725882
# 2      M5A  Downtown Toronto         Harbourfront, Regent Park  43.654260
# 3      M6A        North York  Lawrence Heights, Lawrence Manor  43.718518
# 4      M7A      Queen's Park                      Queen's Park  43.662301
#
#    Longitude  Cluster Labels  1st Most Common Venue 2nd Most Common Venue  \
# 0 -79.329656             0.0      Food & Drink Shop                  Park
# 1 -79.315572             1.0  Portuguese Restaurant           Coffee Shop
# 2 -79.360636             1.0            Coffee Shop                Bakery
# 3 -79.464763             1.0         Clothing Store     Accessories Store
# 4 -79.389494             1.0            Coffee Shop                  Park
#
#   3rd Most Common Venue 4th Most Common Venue  ... 91th Most Common Venue  \
# 0           Yoga Studio        Discount Store  ...             Art Museum
# 1          Hockey Arena          Intersection  ...    Arts & Crafts Store
# 2                   Pub                  Café  ...       Baseball Stadium
# 3           Coffee Shop              Boutique  ...       Asian Restaurant
# 4                   Gym                 Diner  ...                   Bank
#
#   92th Most Common Venue 93th Most Common Venue 94th Most Common Venue  \
# 0            Art Gallery               Aquarium           Antique Shop
# 1             Art Museum            Art Gallery               Aquarium
# 2         Baseball Field                    Bar             Bagel Shop
# 3    Arts & Crafts Store             Art Museum            Art Gallery
# 4                 Bakery             Bagel Shop             Baby Store
#
#   95th Most Common Venue 96th Most Common Venue 97th Most Common Venue  \
# 0    American Restaurant       Airport Terminal        Airport Service
# 1           Antique Shop    American Restaurant       Airport Terminal
# 2             Baby Store              BBQ Joint            Auto Garage
# 3               Aquarium           Antique Shop    American Restaurant
# 4              BBQ Joint          Auto Workshop     Athletics & Sports
#
#   98th Most Common Venue 99th Most Common Venue 100th Most Common Venue
# 0         Airport Lounge           Airport Gate      Airport Food Court
# 1        Airport Service         Airport Lounge            Airport Gate
# 2             Comic Shop     Athletics & Sports        Asian Restaurant
# 3       Airport Terminal        Airport Service          Airport Lounge
# 4     Belgian Restaurant       Asian Restaurant              Art Museum
#
# [5 rows x 106 columns]

# %% [markdown]
# #### Creating map

# %%
# create map
map_clusters = folium.Map(location=[latitude, longitude], zoom_start=11)

# set color scheme for the clusters
x = np.arange(kclusters)
ys = [i + x + (i*x)**2 for i in range(kclusters)]
colors_array = cm.rainbow(np.linspace(0, 1, len(ys)))
rainbow = [colors.rgb2hex(i) for i in colors_array]

# add markers to the map
markers_colors = []
for lat, lon, poi, cluster in zip(toronto_merged['Latitude'], toronto_merged['Longitude'], toronto_merged['Neighborhood'], toronto_merged['Cluster Labels']):
    label = folium.Popup(str(poi) + ' Cluster ' + str(cluster), parse_html=True)
    folium.CircleMarker(
        [lat, lon],
        radius=5,
        popup=label,
        fill=True,
        fill_color=rainbow[cluster-1],
        fill_opacity=0.7).add_to(map_clusters)

map_clusters
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-24-9d5b2e228aa9> in <module>
#      17         popup=label,
#      18         fill=True,
# ---> 19         fill_color=rainbow[cluster-1],
#      20         fill_opacity=0.7).add_to(map_clusters)
#      21
#
# TypeError: list indices must be integers or slices, not float

# %% [markdown]
# #### Examine Clusters

# %%
cluster1 = toronto_merged.loc[toronto_merged['Cluster Labels'] == 1, toronto_merged.columns[[2] + list(range(6, toronto_merged.shape[1]))]]
cluster2 = toronto_merged.loc[toronto_merged['Cluster Labels'] == 2, toronto_merged.columns[[2] + list(range(6, toronto_merged.shape[1]))]]
cluster3 = toronto_merged.loc[toronto_merged['Cluster Labels'] == 3, toronto_merged.columns[[2] + list(range(6, toronto_merged.shape[1]))]]
cluster4 = toronto_merged.loc[toronto_merged['Cluster Labels'] == 4, toronto_merged.columns[[2] + list(range(6, toronto_merged.shape[1]))]]
cluster5 = toronto_merged.loc[toronto_merged['Cluster Labels'] == 5, toronto_merged.columns[[2] + list(range(6, toronto_merged.shape[1]))]]

# %%
cluster1
# Out:
#                                           Neighborhood  \
# 1                                     Victoria Village
# 2                            Harbourfront, Regent Park
# 3                     Lawrence Heights, Lawrence Manor
# 4                                         Queen's Park
# 6                                       Rouge, Malvern
# 7                                      Don Mills North
# 8                      Woodbine Gardens, Parkview Hill
# 9                             Ryerson, Garden District
# 10                                           Glencairn
# 13                    Flemingdon Park, Don Mills South
# 14                                    Woodbine Heights
# 15                                      St. James Town
# 16                                  Humewood-Cedarvale
# 17   Bloordale Gardens, Eringate, Markland Wood, Ol...
# 18                   Guildwood, Morningside, West Hill
# 19                                         The Beaches
# 20                                         Berczy Park
# 22                                              Woburn
# 23                                             Leaside
# 24                                  Central Bay Street
# 25                                            Christie
# 26                                           Cedarbrae
# 27                                   Hillcrest Village
# 28     Bathurst Manor, Downsview North, Wilson Heights
# 29                                    Thorncliffe Park
# 30                            Adelaide, King, Richmond
# 31                        Dovercourt Village, Dufferin
# 32                                 Scarborough Village
# 33                        Fairview, Henry Farm, Oriole
# 34                     Northwood Park, York University
# ..                                                 ...
# 69                       High Park, The Junction South
# 70                                           Westmount
# 71                                   Maryvale, Wexford
# 72                                     Willowdale West
# 73                                  North Toronto West
# 74                 The Annex, North Midtown, Yorkville
# 75                              Parkdale, Roncesvalles
# 76               Canada Post Gateway Processing Centre
# 78                                           Agincourt
# 79                                          Davisville
# 80                      Harbord, University of Toronto
# 81                                  Runnymede, Swansea
# 82             Clarks Corners, Sullivan, Tam O'Shanter
# 83                         Moore Park, Summerhill East
# 84           Chinatown, Grange Park, Kensington Market
# 86   Deer Park, Forest Hill SE, Rathnelly, South Hi...
# 87   CN Tower, Bathurst Quay, Island airport, Harbo...
# 88        Humber Bay Shores, Mimico South, New Toronto
# 89   Albion Gardens, Beaumond Heights, Humbergate, ...
# 90                                     L'Amoreaux West
# 92                     Stn A PO Boxes 25 The Esplanade
# 93                              Alderwood, Long Branch
# 94                                           Northwest
# 96                         Cabbagetown, St. James Town
# 97              First Canadian Place, Underground city
# 98       The Kingsway, Montgomery Road, Old Mill North
# 99                                Church and Wellesley
# 100  Business Reply Mail Processing Centre 969 Eastern
# 101  Humber Bay, King's Mill Park, Kingsway Park So...
# 102  Kingsway Park South West, Mimico NW, The Queen...
#
#          1st Most Common Venue          2nd Most Common Venue  \
# 1        Portuguese Restaurant                    Coffee Shop
# 2                  Coffee Shop                         Bakery
# 3               Clothing Store              Accessories Store
# 4                  Coffee Shop                           Park
# 6         Fast Food Restaurant            Dumpling Restaurant
# 7                         Café           Gym / Fitness Center
# 8         Fast Food Restaurant                    Pizza Place
# 9                  Coffee Shop                 Clothing Store
# 10                         Pub            Filipino Restaurant
# 13                         Gym                    Coffee Shop
# 14                    Pharmacy                           Park
# 15                 Coffee Shop                           Café
# 16                       Trail                          Field
# 17                    Pharmacy                   Liquor Store
# 18          Mexican Restaurant                   Intersection
# 19                       Trail              Health Food Store
# 20                 Coffee Shop                   Cocktail Bar
# 22                 Coffee Shop              Korean Restaurant
# 23                 Coffee Shop            Sporting Goods Shop
# 24                 Coffee Shop                           Café
# 25                        Café                  Grocery Store
# 26            Hakka Restaurant                         Bakery
# 27        Fast Food Restaurant                        Dog Run
# 28                 Coffee Shop                      Pet Store
# 29           Indian Restaurant                   Burger Joint
# 30                 Coffee Shop                           Café
# 31                    Pharmacy                    Supermarket
# 32                  Playground     Construction & Landscaping
# 33              Clothing Store           Fast Food Restaurant
# 34        Caribbean Restaurant                 Massage Studio
# ..                         ...                            ...
# 69                        Café             Mexican Restaurant
# 70              Sandwich Place                    Pizza Place
# 71   Middle Eastern Restaurant                    Auto Garage
# 72                    Pharmacy                    Pizza Place
# 73              Clothing Store                    Coffee Shop
# 74                 Coffee Shop                           Café
# 75              Breakfast Spot                      Gift Shop
# 76                 Coffee Shop                          Hotel
# 78                      Lounge                 Sandwich Place
# 79                 Pizza Place                 Sandwich Place
# 80                        Café                            Bar
# 81                 Coffee Shop                           Café
# 82                 Pizza Place                       Pharmacy
# 83                Tennis Court                     Playground
# 84                        Café  Vegetarian / Vegan Restaurant
# 86                 Coffee Shop                            Pub
# 87             Airport Service               Airport Terminal
# 88                        Café                       Pharmacy
# 89               Grocery Store                       Pharmacy
# 90        Fast Food Restaurant                    Coffee Shop
# 92                 Coffee Shop                           Café
# 93                 Pizza Place                       Pharmacy
# 94         Rental Car Location                            Bar
# 96                 Coffee Shop                           Café
# 97                 Coffee Shop                           Café
# 98                  Smoke Shop                           Park
# 99                 Coffee Shop            Japanese Restaurant
# 100         Light Rail Station                    Yoga Studio
# 101                  Locksmith                           Park
# 102                        Gym         Thrift / Vintage Store
#
#            3rd Most Common Venue 4th Most Common Venue  \
# 1                   Hockey Arena          Intersection
# 2                            Pub                  Café
# 3                    Coffee Shop              Boutique
# 4                            Gym                 Diner
# 6                          Diner        Discount Store
# 7           Caribbean Restaurant   Japanese Restaurant
# 8                      Gastropub        Breakfast Spot
# 9                           Café        Cosmetics Shop
# 10                        Bakery   Japanese Restaurant
# 13                    Beer Store      Asian Restaurant
# 14                    Beer Store           Curling Ice
# 15                         Hotel            Restaurant
# 16                    Playground          Hockey Arena
# 17                   Pizza Place            Beer Store
# 18                   Pizza Place        Breakfast Spot
# 19          Other Great Outdoors                   Pub
# 20                Farmers Market    Seafood Restaurant
# 22   Eastern European Restaurant        Discount Store
# 23        Furniture / Home Store          Burger Joint
# 24            Italian Restaurant        Sandwich Place
# 25                          Park             Nightclub
# 26          Caribbean Restaurant    Athletics & Sports
# 27                          Pool           Golf Course
# 28          Fast Food Restaurant                  Bank
# 29                   Yoga Studio                  Bank
# 30                           Bar            Steakhouse
# 31                        Bakery             Pet Store
# 32                   Yoga Studio   Dumpling Restaurant
# 33                   Coffee Shop         Women's Store
# 34                   Coffee Shop                   Bar
# ..                           ...                   ...
# 69                          Park                 Diner
# 70                Discount Store           Coffee Shop
# 71         Vietnamese Restaurant        Sandwich Place
# 72                       Butcher        Discount Store
# 73           Sporting Goods Shop           Yoga Studio
# 74                Sandwich Place           Pizza Place
# 75                     Bookstore      Cuban Restaurant
# 76          Gym / Fitness Center        Sandwich Place
# 78                Breakfast Spot          Skating Rink
# 79                  Dessert Shop           Coffee Shop
# 80           Japanese Restaurant             Bookstore
# 81              Sushi Restaurant    Italian Restaurant
# 82               Thai Restaurant          Noodle House
# 83                     Drugstore    Dim Sum Restaurant
# 84                           Bar    Mexican Restaurant
# 86                    Bagel Shop   Fried Chicken Joint
# 87              Sculpture Garden                   Bar
# 88           Fried Chicken Joint           Pizza Place
# 89           Fried Chicken Joint           Pizza Place
# 90            Chinese Restaurant              Pharmacy
# 92                    Restaurant    Seafood Restaurant
# 93                  Skating Rink           Coffee Shop
# 94                     Drugstore           Yoga Studio
# 96                        Bakery    Italian Restaurant
# 97                         Hotel            Steakhouse
# 98                         River                  Pool
# 99                       Gay Bar      Sushi Restaurant
# 100                Auto Workshop                  Park
# 101                         Pool        Baseball Field
# 102         Fast Food Restaurant           Social Club
#
#          5th Most Common Venue      6th Most Common Venue  \
# 1          Dumpling Restaurant                      Diner
# 2                         Park       Gym / Fitness Center
# 3                   Shoe Store         Miscellaneous Shop
# 4          Japanese Restaurant           Sushi Restaurant
# 6                      Dog Run           Doner Restaurant
# 7               Baseball Field                  Drugstore
# 8                         Bank               Intersection
# 9    Middle Eastern Restaurant         Italian Restaurant
# 10         Dumpling Restaurant                    Dog Run
# 13          Italian Restaurant             Clothing Store
# 14              Cosmetics Shop               Skating Rink
# 15          Italian Restaurant               Cocktail Bar
# 16                 Yoga Studio                      Diner
# 17           Convenience Store                Coffee Shop
# 18           Electronics Store             Medical Center
# 19                 Yoga Studio         Dim Sum Restaurant
# 20                 Cheese Shop                       Café
# 22                     Dog Run           Doner Restaurant
# 23                  Beer Store           Sushi Restaurant
# 24                Burger Joint             Ice Cream Shop
# 25           Convenience Store                 Baby Store
# 26             Thai Restaurant                       Bank
# 27    Mediterranean Restaurant                  Drugstore
# 28                  Restaurant  Middle Eastern Restaurant
# 29               Grocery Store        Housing Development
# 30         American Restaurant               Burger Joint
# 31                  Smoke Shop  Middle Eastern Restaurant
# 32                       Diner             Discount Store
# 33                      Bakery        Sporting Goods Shop
# 34                 Yoga Studio        Dumpling Restaurant
# ..                         ...                        ...
# 69          Italian Restaurant                     Bakery
# 70          Chinese Restaurant               Intersection
# 71               Shopping Mall             Breakfast Spot
# 72                 Coffee Shop               Home Service
# 73          Italian Restaurant         Salon / Barbershop
# 74         American Restaurant          Indian Restaurant
# 75                         Bar                    Dog Run
# 76   Middle Eastern Restaurant              Burrito Place
# 78          Chinese Restaurant                  Drugstore
# 79                         Gym         Italian Restaurant
# 80              Sandwich Place                    Theater
# 81                    Tea Room              Smoothie Shop
# 82          Chinese Restaurant             Breakfast Spot
# 83                       Diner             Discount Store
# 84                      Bakery      Vietnamese Restaurant
# 86          Light Rail Station               Liquor Store
# 87               Boat or Ferry                   Boutique
# 88                  Restaurant             Sandwich Place
# 89                 Coffee Shop             Sandwich Place
# 90              Sandwich Place                        Gym
# 92                    Beer Bar                      Hotel
# 93                        Pool                        Pub
# 94          Dim Sum Restaurant             Discount Store
# 96                  Restaurant                        Pub
# 97                  Restaurant         Seafood Restaurant
# 98                  Donut Shop         Dim Sum Restaurant
# 99                  Restaurant                       Café
# 100       Gym / Fitness Center                Pizza Place
# 101        Dumpling Restaurant             Discount Store
# 102             Sandwich Place               Burger Joint
#
#          7th Most Common Venue        8th Most Common Venue  \
# 1               Discount Store                      Dog Run
# 2           Mexican Restaurant               Breakfast Spot
# 3       Furniture / Home Store        Vietnamese Restaurant
# 4                          Bar                         Café
# 6                   Donut Shop                    Drugstore
# 7               Discount Store                      Dog Run
# 8           Athletics & Sports                     Pharmacy
# 9                     Tea Room          Japanese Restaurant
# 10            Doner Restaurant                   Donut Shop
# 13          Chinese Restaurant                   Restaurant
# 14                   Drugstore               Discount Store
# 15                      Bakery               Cosmetics Shop
# 16              Discount Store                      Dog Run
# 17                        Café                    Drugstore
# 18         Rental Car Location                  Yoga Studio
# 19                       Diner               Discount Store
# 20                      Bakery                     Beer Bar
# 22                  Donut Shop                    Drugstore
# 23                 Supermarket                   Restaurant
# 24   Middle Eastern Restaurant                  Salad Place
# 25          Italian Restaurant                  Coffee Shop
# 26         Fried Chicken Joint                  Yoga Studio
# 27                       Diner               Discount Store
# 28                 Supermarket          Fried Chicken Joint
# 29              Discount Store                         Park
# 30             Thai Restaurant                   Restaurant
# 31                        Café                   Playground
# 32                     Dog Run             Doner Restaurant
# 33                    Tea Room          Japanese Restaurant
# 34                     Dog Run             Doner Restaurant
# ..                         ...                          ...
# 69              Discount Store    Cajun / Creole Restaurant
# 70   Middle Eastern Restaurant                  Yoga Studio
# 71           Electronics Store  Eastern European Restaurant
# 72                   Drugstore                        Diner
# 73                  Restaurant          Rental Car Location
# 74                   BBQ Joint            Jewish Restaurant
# 75                Dessert Shop                   Restaurant
# 76         American Restaurant          Fried Chicken Joint
# 78              Discount Store                      Dog Run
# 79                  Restaurant              Thai Restaurant
# 80                  Restaurant                       Bakery
# 81          Falafel Restaurant                   Restaurant
# 82          Italian Restaurant                         Bank
# 83                     Dog Run             Doner Restaurant
# 84         Dumpling Restaurant           Chinese Restaurant
# 86                 Pizza Place                   Restaurant
# 87             Harbor / Marina               Airport Lounge
# 88            Business Service         Fast Food Restaurant
# 89                  Beer Store         Fast Food Restaurant
# 90               Grocery Store                  Pizza Place
# 92          Italian Restaurant                 Cocktail Bar
# 93              Sandwich Place                          Gym
# 94                     Dog Run             Doner Restaurant
# 96                      Market                  Pizza Place
# 97                         Gym                          Bar
# 98                       Diner               Discount Store
# 99        Fast Food Restaurant                    Gastropub
# 100                 Restaurant                      Butcher
# 101                    Dog Run             Doner Restaurant
# 102              Burrito Place              Supplement Shop
#
#            9th Most Common Venue  ...       91th Most Common Venue  \
# 1               Doner Restaurant  ...          Arts & Crafts Store
# 2                     Restaurant  ...             Baseball Stadium
# 3                  Women's Store  ...             Asian Restaurant
# 4             Italian Restaurant  ...                         Bank
# 6    Eastern European Restaurant  ...                  Art Gallery
# 7               Doner Restaurant  ...          Arts & Crafts Store
# 8           Gym / Fitness Center  ...             Asian Restaurant
# 9                         Bakery  ...           Falafel Restaurant
# 10                     Drugstore  ...                   Art Museum
# 13            Dim Sum Restaurant  ...                Auto Workshop
# 14                       Dog Run  ...          Arts & Crafts Store
# 15                Clothing Store  ...                      Airport
# 16              Doner Restaurant  ...          Arts & Crafts Store
# 17                Discount Store  ...             Asian Restaurant
# 18                Discount Store  ...             Asian Restaurant
# 19                       Dog Run  ...          Arts & Crafts Store
# 20                    Steakhouse  ...                Boat or Ferry
# 22           Dumpling Restaurant  ...                   Art Museum
# 23             Fish & Chips Shop  ...                          Bar
# 24               Bubble Tea Shop  ...                 Climbing Gym
# 25                         Diner  ...             Asian Restaurant
# 26                    Donut Shop  ...          Arts & Crafts Store
# 27              Doner Restaurant  ...                   Art Museum
# 28            Frozen Yogurt Shop  ...                    BBQ Joint
# 29                           Gym  ...           Belgian Restaurant
# 30                Cosmetics Shop  ...            Fish & Chips Shop
# 31         Portuguese Restaurant  ...                   Baby Store
# 32                    Donut Shop  ...                   Art Museum
# 33                Baseball Field  ...                   Beer Store
# 34                    Donut Shop  ...          Arts & Crafts Store
# ..                           ...  ...                          ...
# 69           Fried Chicken Joint  ...                Auto Workshop
# 70              Doner Restaurant  ...             Asian Restaurant
# 71           Dumpling Restaurant  ...             Asian Restaurant
# 72                       Dog Run  ...          Arts & Crafts Store
# 73                          Park  ...                          Bar
# 74                         Plaza  ...                       Bakery
# 75                 Movie Theater  ...             Asian Restaurant
# 76      Mediterranean Restaurant  ...           Athletics & Sports
# 78              Doner Restaurant  ...             Asian Restaurant
# 79                          Café  ...                  Bridal Shop
# 80         College Arts Building  ...              Bubble Tea Shop
# 81                     Bookstore  ...                       Bakery
# 82           Fried Chicken Joint  ...           College Rec Center
# 83                    Donut Shop  ...                   Art Museum
# 84                   Coffee Shop  ...  Eastern European Restaurant
# 86                    Sports Bar  ...              Airport Service
# 87                  Airport Gate  ...                   Bagel Shop
# 88                        Bakery  ...                  Auto Garage
# 89        Gluten-free Restaurant  ...             Asian Restaurant
# 90                Breakfast Spot  ...             Asian Restaurant
# 92                   Art Gallery  ...            Food & Drink Shop
# 93              Airport Terminal  ...                          Bar
# 94                    Donut Shop  ...                   Art Museum
# 96                          Park  ...                 Costume Shop
# 97           American Restaurant  ...          Dumpling Restaurant
# 98                       Dog Run  ...          Arts & Crafts Store
# 99                   Pizza Place  ...             Tapas Restaurant
# 100                Burrito Place  ...                    BBQ Joint
# 101                   Donut Shop  ...          Arts & Crafts Store
# 102                       Bakery  ...                  Auto Garage
#
#     92th Most Common Venue 93th Most Common Venue     94th Most Common Venue  \
# 1               Art Museum            Art Gallery                   Aquarium
# 2           Baseball Field                    Bar                 Bagel Shop
# 3      Arts & Crafts Store             Art Museum                Art Gallery
# 4                   Bakery             Bagel Shop                 Baby Store
# 6                 Aquarium           Antique Shop        American Restaurant
# 7               Art Museum            Art Gallery                   Aquarium
# 8      Arts & Crafts Store             Art Museum                Art Gallery
# 9       Dim Sum Restaurant         Farmers Market                   Festival
# 10             Art Gallery               Aquarium               Antique Shop
# 13             Auto Garage     Athletics & Sports        Arts & Crafts Store
# 14              Art Museum            Art Gallery                   Aquarium
# 15    Fast Food Restaurant        College Stadium            Coworking Space
# 16              Art Museum            Art Gallery                   Aquarium
# 17     Arts & Crafts Store             Art Museum                Art Gallery
# 18     Arts & Crafts Store             Art Museum                Art Gallery
# 19              Art Museum            Art Gallery                   Aquarium
# 20               Bike Shop             Beer Store            Bed & Breakfast
# 22             Art Gallery               Aquarium               Antique Shop
# 23                  Bakery             Baby Store                  BBQ Joint
# 24            Concert Hall            Auto Garage                   Beer Bar
# 25     Arts & Crafts Store             Art Museum                Art Gallery
# 26              Art Museum            Art Gallery                   Aquarium
# 27             Art Gallery               Aquarium               Antique Shop
# 28           Auto Workshop            Auto Garage         Athletics & Sports
# 29              Beer Store               Beer Bar            Bed & Breakfast
# 30             Fish Market            Flea Market                Flower Shop
# 31               BBQ Joint          Auto Workshop                Auto Garage
# 32             Art Gallery               Aquarium               Antique Shop
# 33                Beer Bar        Bed & Breakfast                      Beach
# 34              Art Museum            Art Gallery                   Aquarium
# ..                     ...                    ...                        ...
# 69             Auto Garage     Athletics & Sports           Asian Restaurant
# 70     Arts & Crafts Store             Art Museum                Art Gallery
# 71     Arts & Crafts Store             Art Museum                Art Gallery
# 72              Art Museum            Art Gallery                   Aquarium
# 73                    Bank                 Bakery                Wings Joint
# 74              Bagel Shop             Baby Store              Auto Workshop
# 75     Arts & Crafts Store             Art Museum                Art Gallery
# 76        Asian Restaurant    Arts & Crafts Store                 Art Museum
# 78     Arts & Crafts Store             Art Museum                Art Gallery
# 79             Auto Garage         Breakfast Spot       Brazilian Restaurant
# 80             Bridal Shop                Brewery             Breakfast Spot
# 81              Bagel Shop             Baby Store                  BBQ Joint
# 82        Asian Restaurant    Arts & Crafts Store                 Art Museum
# 83             Art Gallery               Aquarium               Antique Shop
# 84    Ethiopian Restaurant         Clothing Store             Cosmetics Shop
# 86      Basketball Stadium       Basketball Court             Baseball Field
# 87              Comic Shop             Baby Store                  BBQ Joint
# 88      Athletics & Sports       Asian Restaurant        Arts & Crafts Store
# 89     Arts & Crafts Store             Art Museum                Art Gallery
# 90     Arts & Crafts Store             Art Museum                Art Gallery
# 92      Dim Sum Restaurant               Festival                Flower Shop
# 93                    Bank                 Bakery                 Bagel Shop
# 94             Art Gallery               Aquarium               Antique Shop
# 96         Coworking Space            Bridal Shop  Cajun / Creole Restaurant
# 97               Drugstore             Donut Shop                Yoga Studio
# 98              Art Museum            Art Gallery                   Aquarium
# 99          Farmers Market     Falafel Restaurant                Event Space
# 100            Auto Garage     Athletics & Sports           Asian Restaurant
# 101             Art Museum            Art Gallery                   Aquarium
# 102     Athletics & Sports       Asian Restaurant        Arts & Crafts Store
#
#     95th Most Common Venue   96th Most Common Venue  \
# 1             Antique Shop      American Restaurant
# 2               Baby Store                BBQ Joint
# 3                 Aquarium             Antique Shop
# 4                BBQ Joint            Auto Workshop
# 6         Airport Terminal          Airport Service
# 7             Antique Shop      American Restaurant
# 8                 Aquarium             Antique Shop
# 9                    Field      Filipino Restaurant
# 10     American Restaurant         Airport Terminal
# 13              Art Museum              Art Gallery
# 14            Antique Shop      American Restaurant
# 15            Costume Shop          Bubble Tea Shop
# 16            Antique Shop      American Restaurant
# 17                Aquarium             Antique Shop
# 18                Aquarium             Antique Shop
# 19            Antique Shop      American Restaurant
# 20        Basketball Court         Baseball Stadium
# 22     American Restaurant         Airport Terminal
# 23           Auto Workshop              Auto Garage
# 24         Bed & Breakfast                    Beach
# 25                Aquarium             Antique Shop
# 26            Antique Shop      American Restaurant
# 27     American Restaurant         Airport Terminal
# 28        Asian Restaurant      Arts & Crafts Store
# 29      Basketball Stadium  Comfort Food Restaurant
# 30                    Food              Yoga Studio
# 31      Athletics & Sports         Asian Restaurant
# 32     American Restaurant         Airport Terminal
# 33      Basketball Stadium         Basketball Court
# 34            Antique Shop      American Restaurant
# ..                     ...                      ...
# 69              Art Museum              Art Gallery
# 70                Aquarium             Antique Shop
# 71                Aquarium             Antique Shop
# 72            Antique Shop      American Restaurant
# 73              Baby Store                BBQ Joint
# 74             Auto Garage       Athletics & Sports
# 75                Aquarium             Antique Shop
# 76             Art Gallery                 Aquarium
# 78                Aquarium             Antique Shop
# 79                Boutique                Bookstore
# 80    Brazilian Restaurant                 Boutique
# 81           Auto Workshop              Auto Garage
# 82             Art Gallery                 Aquarium
# 83     American Restaurant         Airport Terminal
# 84                  Bistro               Beer Store
# 86          Breakfast Spot         Airport Terminal
# 87           Auto Workshop              Auto Garage
# 88              Art Museum              Art Gallery
# 89                Aquarium             Antique Shop
# 90                Aquarium             Antique Shop
# 92             Yoga Studio        Convenience Store
# 93              Baby Store                BBQ Joint
# 94     American Restaurant         Airport Terminal
# 96              Bagel Shop                      Bar
# 97            Climbing Gym               Comic Shop
# 98            Antique Shop      American Restaurant
# 99     Empanada Restaurant        Electronics Store
# 100    Arts & Crafts Store               Art Museum
# 101           Antique Shop      American Restaurant
# 102             Art Museum              Art Gallery
#
#           97th Most Common Venue   98th Most Common Venue  \
# 1               Airport Terminal          Airport Service
# 2                    Auto Garage               Comic Shop
# 3            American Restaurant         Airport Terminal
# 4             Athletics & Sports       Belgian Restaurant
# 6                 Airport Lounge             Airport Gate
# 7               Airport Terminal          Airport Service
# 8            American Restaurant         Airport Terminal
# 9              Fish & Chips Shop            Deli / Bodega
# 10               Airport Service           Airport Lounge
# 13                      Aquarium             Antique Shop
# 14              Airport Terminal          Airport Service
# 15                   Bridal Shop                  Brewery
# 16              Airport Terminal          Airport Service
# 17           American Restaurant         Airport Terminal
# 18           American Restaurant         Airport Terminal
# 19              Airport Terminal          Airport Service
# 20                Baseball Field                      Bar
# 22               Airport Service           Airport Lounge
# 23              Asian Restaurant  Comfort Food Restaurant
# 24            Basketball Stadium         Basketball Court
# 25           American Restaurant         Airport Terminal
# 26              Airport Terminal          Airport Service
# 27               Airport Service           Airport Lounge
# 28                    Art Museum              Art Gallery
# 29              Basketball Court         Baseball Stadium
# 30                  Climbing Gym        Convenience Store
# 31           Arts & Crafts Store               Art Museum
# 32               Airport Service           Airport Lounge
# 33              Baseball Stadium                      Bar
# 34              Airport Terminal          Airport Service
# ..                           ...                      ...
# 69                      Aquarium             Antique Shop
# 70           American Restaurant         Airport Terminal
# 71           American Restaurant         Airport Terminal
# 72              Airport Terminal          Airport Service
# 73                 Auto Workshop              Auto Garage
# 74              Asian Restaurant      Arts & Crafts Store
# 75           American Restaurant         Airport Terminal
# 76                  Antique Shop         Airport Terminal
# 78           American Restaurant         Airport Terminal
# 79                 Boat or Ferry                   Bistro
# 80              Asian Restaurant            Boat or Ferry
# 81            Athletics & Sports         Asian Restaurant
# 82                  Antique Shop      American Restaurant
# 83               Airport Service           Airport Lounge
# 84                         Beach       Basketball Stadium
# 86                           Bar                     Bank
# 87            Athletics & Sports         Asian Restaurant
# 88                      Aquarium             Antique Shop
# 89           American Restaurant         Airport Terminal
# 90           American Restaurant         Airport Terminal
# 92            Athletics & Sports               Beer Store
# 93                 Auto Workshop              Auto Garage
# 94               Airport Service           Airport Lounge
# 96              Business Service              Bus Station
# 97                 Auto Workshop       Belgian Restaurant
# 98              Airport Terminal          Airport Service
# 99   Eastern European Restaurant      Dumpling Restaurant
# 100                  Art Gallery                 Aquarium
# 101             Airport Terminal          Airport Service
# 102                     Aquarium             Antique Shop
#
#     99th Most Common Venue      100th Most Common Venue
# 1           Airport Lounge                 Airport Gate
# 2       Athletics & Sports             Asian Restaurant
# 3          Airport Service               Airport Lounge
# 4         Asian Restaurant                   Art Museum
# 6       Airport Food Court                      Airport
# 7           Airport Lounge                 Airport Gate
# 8          Airport Service               Airport Lounge
# 9             Dance Studio  Eastern European Restaurant
# 10            Airport Gate           Airport Food Court
# 13     American Restaurant             Airport Terminal
# 14          Airport Lounge                 Airport Gate
# 15    Brazilian Restaurant                     Boutique
# 16          Airport Lounge                 Airport Gate
# 17         Airport Service               Airport Lounge
# 18         Airport Service               Airport Lounge
# 19          Airport Lounge                 Airport Gate
# 20                    Bank                   Baby Store
# 22            Airport Gate           Airport Food Court
# 23     Arts & Crafts Store                   Art Museum
# 24        Baseball Stadium               Baseball Field
# 25         Airport Service               Airport Lounge
# 26          Airport Lounge                 Airport Gate
# 27            Airport Gate           Airport Food Court
# 28                Aquarium                 Antique Shop
# 29             Art Gallery               Baseball Field
# 30               Bike Shop                   Beer Store
# 31             Art Gallery                     Aquarium
# 32            Airport Gate           Airport Food Court
# 33              Bagel Shop                   Baby Store
# 34          Airport Lounge                 Airport Gate
# ..                     ...                          ...
# 69     American Restaurant             Airport Terminal
# 70         Airport Service               Airport Lounge
# 71         Airport Service               Airport Lounge
# 72          Airport Lounge                 Airport Gate
# 73        Asian Restaurant                     Beer Bar
# 74              Art Museum                  Art Gallery
# 75         Airport Service               Airport Lounge
# 76         Airport Service               Airport Lounge
# 78         Airport Service               Airport Lounge
# 79               Bike Shop                   Beer Store
# 80               Bike Shop               Airport Lounge
# 81     Arts & Crafts Store                   Art Museum
# 82        Airport Terminal              Airport Service
# 83            Airport Gate           Airport Food Court
# 84        Basketball Court             Baseball Stadium
# 86                  Bakery                 Antique Shop
# 87     Arts & Crafts Store                   Art Museum
# 88        Airport Terminal              Airport Service
# 89         Airport Service               Airport Lounge
# 90         Airport Service               Airport Lounge
# 92         Bed & Breakfast                        Beach
# 93      Athletics & Sports             Asian Restaurant
# 94            Airport Gate           Airport Food Court
# 96                Bus Line               Baseball Field
# 97              Beer Store              Bed & Breakfast
# 98          Airport Lounge                 Airport Gate
# 99               Drugstore                   Donut Shop
# 100           Antique Shop          American Restaurant
# 101         Airport Lounge                 Airport Gate
# 102    American Restaurant             Airport Terminal
#
# [87 rows x 101 columns]

# %%
cluster2
# Out:
#                                          Neighborhood 1st Most Common Venue  \
# 61                                      Lawrence Park                  Park
# 77  Kingsview Village, Martin Grove Gardens, Richv...           Pizza Place
#
#    2nd Most Common Venue 3rd Most Common Venue 4th Most Common Venue  \
# 61              Bus Line           Swim School           Yoga Studio
# 77     Mobile Phone Shop                  Park              Bus Line
#
#    5th Most Common Venue 6th Most Common Venue 7th Most Common Venue  \
# 61             Drugstore        Discount Store               Dog Run
# 77           Yoga Studio             Drugstore        Discount Store
#
#    8th Most Common Venue 9th Most Common Venue  ... 91th Most Common Venue  \
# 61      Doner Restaurant            Donut Shop  ...             Art Museum
# 77               Dog Run      Doner Restaurant  ...    Arts & Crafts Store
#
#    92th Most Common Venue 93th Most Common Venue 94th Most Common Venue  \
# 61            Art Gallery               Aquarium           Antique Shop
# 77             Art Museum            Art Gallery               Aquarium
#
#    95th Most Common Venue 96th Most Common Venue 97th Most Common Venue  \
# 61    American Restaurant       Airport Terminal        Airport Service
# 77           Antique Shop    American Restaurant       Airport Terminal
#
#    98th Most Common Venue 99th Most Common Venue 100th Most Common Venue
# 61         Airport Lounge           Airport Gate      Airport Food Court
# 77        Airport Service         Airport Lounge            Airport Gate
#
# [2 rows x 101 columns]

# %%
cluster3 #bars
# Out:
#                                          Neighborhood 1st Most Common Venue  \
# 11  Cloverdale, Islington, Martin Grove, Princess ...                  Bank
#
#    2nd Most Common Venue 3rd Most Common Venue 4th Most Common Venue  \
# 11           Yoga Studio   Dumpling Restaurant        Discount Store
#
#    5th Most Common Venue 6th Most Common Venue 7th Most Common Venue  \
# 11               Dog Run      Doner Restaurant            Donut Shop
#
#    8th Most Common Venue        9th Most Common Venue  ...  \
# 11             Drugstore  Eastern European Restaurant  ...
#
#    91th Most Common Venue 92th Most Common Venue 93th Most Common Venue  \
# 11            Art Gallery               Aquarium           Antique Shop
#
#    94th Most Common Venue 95th Most Common Venue 96th Most Common Venue  \
# 11    American Restaurant       Airport Terminal        Airport Service
#
#    97th Most Common Venue 98th Most Common Venue 99th Most Common Venue  \
# 11         Airport Lounge           Airport Gate     Airport Food Court
#
#    100th Most Common Venue
# 11                 Airport
#
# [1 rows x 101 columns]

# %%
cluster4
# Out:
#                               Neighborhood 1st Most Common Venue  \
# 12  Highland Creek, Rouge Hill, Port Union                   Bar
#
#    2nd Most Common Venue 3rd Most Common Venue 4th Most Common Venue  \
# 12           Yoga Studio   Dumpling Restaurant        Discount Store
#
#    5th Most Common Venue 6th Most Common Venue 7th Most Common Venue  \
# 12               Dog Run      Doner Restaurant            Donut Shop
#
#    8th Most Common Venue        9th Most Common Venue  ...  \
# 12             Drugstore  Eastern European Restaurant  ...
#
#    91th Most Common Venue 92th Most Common Venue 93th Most Common Venue  \
# 12            Art Gallery               Aquarium           Antique Shop
#
#    94th Most Common Venue 95th Most Common Venue 96th Most Common Venue  \
# 12    American Restaurant       Airport Terminal        Airport Service
#
#    97th Most Common Venue 98th Most Common Venue 99th Most Common Venue  \
# 12         Airport Lounge           Airport Gate     Airport Food Court
#
#    100th Most Common Venue
# 12                 Airport
#
# [1 rows x 101 columns]

# %%
cluster5
# Out:
# Empty DataFrame
# Columns: [Neighborhood, 1st Most Common Venue, 2nd Most Common Venue, 3rd Most Common Venue, 4th Most Common Venue, 5th Most Common Venue, 6th Most Common Venue, 7th Most Common Venue, 8th Most Common Venue, 9th Most Common Venue, 10th Most Common Venue, 11th Most Common Venue, 12th Most Common Venue, 13th Most Common Venue, 14th Most Common Venue, 15th Most Common Venue, 16th Most Common Venue, 17th Most Common Venue, 18th Most Common Venue, 19th Most Common Venue, 20th Most Common Venue, 21th Most Common Venue, 22th Most Common Venue, 23th Most Common Venue, 24th Most Common Venue, 25th Most Common Venue, 26th Most Common Venue, 27th Most Common Venue, 28th Most Common Venue, 29th Most Common Venue, 30th Most Common Venue, 31th Most Common Venue, 32th Most Common Venue, 33th Most Common Venue, 34th Most Common Venue, 35th Most Common Venue, 36th Most Common Venue, 37th Most Common Venue, 38th Most Common Venue, 39th Most Common Venue, 40th Most Common Venue, 41th Most Common Venue, 42th Most Common Venue, 43th Most Common Venue, 44th Most Common Venue, 45th Most Common Venue, 46th Most Common Venue, 47th Most Common Venue, 48th Most Common Venue, 49th Most Common Venue, 50th Most Common Venue, 51th Most Common Venue, 52th Most Common Venue, 53th Most Common Venue, 54th Most Common Venue, 55th Most Common Venue, 56th Most Common Venue, 57th Most Common Venue, 58th Most Common Venue, 59th Most Common Venue, 60th Most Common Venue, 61th Most Common Venue, 62th Most Common Venue, 63th Most Common Venue, 64th Most Common Venue, 65th Most Common Venue, 66th Most Common Venue, 67th Most Common Venue, 68th Most Common Venue, 69th Most Common Venue, 70th Most Common Venue, 71th Most Common Venue, 72th Most Common Venue, 73th Most Common Venue, 74th Most Common Venue, 75th Most Common Venue, 76th Most Common Venue, 77th Most Common Venue, 78th Most Common Venue, 79th Most Common Venue, 80th Most Common Venue, 81th Most Common Venue, 82th Most Common Venue, 83th Most Common Venue, 84th Most Common Venue, 85th Most Common Venue, 86th Most Common Venue, 87th Most Common Venue, 88th Most Common Venue, 89th Most Common Venue, 90th Most Common Venue, 91th Most Common Venue, 92th Most Common Venue, 93th Most Common Venue, 94th Most Common Venue, 95th Most Common Venue, 96th Most Common Venue, 97th Most Common Venue, 98th Most Common Venue, 99th Most Common Venue, ...]
# Index: []
#
# [0 rows x 101 columns]
